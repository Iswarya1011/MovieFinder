# %%
import pandas as pd

# %%
df1 = pd.read_csv("Data/data_imdb_Action.csv", sep = ";")
df2 = pd.read_csv("Data/data_imdb_Adventure.csv", sep = ";")
df3 = pd.read_csv("Data/data_imdb_Animation.csv", sep = ";")
df4 = pd.read_csv("Data/data_imdb_Biography.csv", sep = ";")
df5 = pd.read_csv("Data/data_imdb_Comedy.csv", sep = ";")
df6 = pd.read_csv("Data/data_imdb_Crime.csv", sep = ";")
df7 = pd.read_csv("Data/data_imdb_Drama.csv", sep = ";")
df8 = pd.read_csv("Data/data_imdb_Family.csv", sep = ";")
df9 = pd.read_csv("Data/data_imdb_Fantasy.csv", sep = ";")
df10 = pd.read_csv("Data/data_imdb_Film-Noir.csv", sep = ";")
df11 = pd.read_csv("Data/data_imdb_History.csv", sep = ";")
df12 = pd.read_csv("Data/data_imdb_Horror.csv", sep = ";")
df13 = pd.read_csv("Data/data_imdb_Music.csv", sep = ";")
df14 = pd.read_csv("Data/data_imdb_Musical.csv", sep = ";")
df15 = pd.read_csv("Data/data_imdb_Mystery.csv", sep = ";")
df16 = pd.read_csv("Data/data_imdb_Romance.csv", sep = ";")
df17 = pd.read_csv("Data/data_imdb_Sci-Fi.csv", sep = ";")
df18 = pd.read_csv("Data/data_imdb_Sport.csv", sep = ";")
df19 = pd.read_csv("Data/data_imdb_Thriller.csv", sep = ";")
df20 = pd.read_csv("Data/data_imdb_War.csv", sep = ";")
df21 = pd.read_csv("Data/data_imdb_Western.csv", sep = ";")

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21],  ignore_index=True)
df = df.drop(columns= ["Unnamed: 0"])
df
# Out:
#                                              name  year   certificate  \
# 0             The Dark Knight : Le Chevalier noir  2008  Tous publics
# 1      Le Seigneur des anneaux : Le Retour du roi  2003  Tous publics
# 2              Kill Bill: The Whole Bloody Affair  2011           NaN
# 3                                       Inception  2010  Tous publics
# 4        Le Seigneur des anneaux : Les Deux Tours  2002  Tous publics
# ...                                           ...   ...           ...
# 23932       Apportez-moi la tête d'Alfredo Garcia  1974            12
# 23933                  L'homme des hautes plaines  1973  Tous publics
# 23934                                Les cow-boys  1972  Tous publics
# 23935                  100 dollars pour un shérif  1969            12
# 23936                                      Hombre  1967  Tous publics
#
#        runtime                                            genre  rating  \
# ...

# %%
df.to_csv("all_films.csv", sep=';')
