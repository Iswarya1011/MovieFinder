# %% [markdown]
# SOFTWARE

# %%
import pandas as pd

# %%
df = pd.read_csv("data_films.csv",sep=";")
df
# Out:
#                                              name  year   certificate  \
# 0             The Dark Knight : Le Chevalier noir  2008  Tous publics
# 1      Le Seigneur des anneaux : Le Retour du roi  2003  Tous publics
# 2              Kill Bill: The Whole Bloody Affair  2011           NaN
# 3                                       Inception  2010  Tous publics
# 4        Le Seigneur des anneaux : Les Deux Tours  2002  Tous publics
# ...                                           ...   ...           ...
# 23932      Apportez-moi la t̻te d'Alfredo Garcia  1974            12
# 23933                  L'homme des hautes plaines  1973  Tous publics
# 23934                                Les cow-boys  1972  Tous publics
# 23935                 100 dollars pour un sh̩rif  1969            12
# 23936                                      Hombre  1967  Tous publics
#
#        runtime                                            genre  rating  \
# ...

# %%
df = df.drop_duplicates(subset = ['name', 'year'],keep = 'last').reset_index(drop = True)
df
# Out:
#                                                name  year   certificate  \
# 0                               Les anges de Boston  1999            16
# 1     Fist of Legend: La Nouvelle Fureur de Vaincre  1994  Tous publics
# 2          Mission: Impossible - Protocole fant̫me  2011  Tous publics
# 3                    L'odyss̩e du sous-marin Nerka  1958           NaN
# 4                                         Old Henry  2021           NaN
# ...                                             ...   ...           ...
# 8402         Apportez-moi la t̻te d'Alfredo Garcia  1974            12
# 8403                     L'homme des hautes plaines  1973  Tous publics
# 8404                                   Les cow-boys  1972  Tous publics
# 8405                    100 dollars pour un sh̩rif  1969            12
# 8406                                         Hombre  1967  Tous publics
#
#       runtime                                            genre  rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8407 entries, 0 to 8406
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         8407 non-null   object
#  1   year         8407 non-null   object
#  2   certificate  7949 non-null   object
#  3   runtime      8407 non-null   int64
#  4   genre        8407 non-null   object
#  5   rating       8407 non-null   float64
#  6   metascore    8407 non-null   int64
#  7   text-muted   8407 non-null   object
#  8   director     8407 non-null   object
#  9   stars        8407 non-null   object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 656.9+ KB

# %%
df.replace(-1, 0)
# Out:
#                                                name  year   certificate  \
# 0                               Les anges de Boston  1999            16
# 1     Fist of Legend: La Nouvelle Fureur de Vaincre  1994  Tous publics
# 2          Mission: Impossible - Protocole fant̫me  2011  Tous publics
# 3                    L'odyss̩e du sous-marin Nerka  1958           NaN
# 4                                         Old Henry  2021           NaN
# ...                                             ...   ...           ...
# 8402         Apportez-moi la t̻te d'Alfredo Garcia  1974            12
# 8403                     L'homme des hautes plaines  1973  Tous publics
# 8404                                   Les cow-boys  1972  Tous publics
# 8405                    100 dollars pour un sh̩rif  1969            12
# 8406                                         Hombre  1967  Tous publics
#
#       runtime                                            genre  rating  \
# ...

# %%
df['certificate'] = df['certificate'].fillna("Pas disponible")
df
# Out:
#                                                name  year     certificate  \
# 0                               Les anges de Boston  1999              16
# 1     Fist of Legend: La Nouvelle Fureur de Vaincre  1994    Tous publics
# 2          Mission: Impossible - Protocole fant̫me  2011    Tous publics
# 3                    L'odyss̩e du sous-marin Nerka  1958  Pas disponible
# 4                                         Old Henry  2021  Pas disponible
# ...                                             ...   ...             ...
# 8402         Apportez-moi la t̻te d'Alfredo Garcia  1974              12
# 8403                     L'homme des hautes plaines  1973    Tous publics
# 8404                                   Les cow-boys  1972    Tous publics
# 8405                    100 dollars pour un sh̩rif  1969              12
# 8406                                         Hombre  1967    Tous publics
#
#       runtime                                            genre  rating  \
# ...
