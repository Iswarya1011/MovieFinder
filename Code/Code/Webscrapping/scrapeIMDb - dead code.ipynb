# %%
from bs4 import BeautifulSoup
import requests

# %%
import numpy as np

# %%
from shutil import ExecError

from numpy import argmax
import pandas as pd

page_infs = []

try:
    source = requests.get("https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1&explore=genres&ref_=adv_nxt")
    source.raise_for_status()

    soup = BeautifulSoup(source.text, "html.parser")
    
    movies = soup.find('div', class_ = "lister-list").find_all("div",class_="lister-item mode-advanced")

    for movie in movies:

        infs = {}

        try:

            lic = movie.find("div", class_="lister-item-content")

            try:
                number = lic.find("span", class_="lister-item-index unbold text-primary").text
            except Exception:
                number = "NaN"
            infs["number"] = number

            try:
                name = lic.a.text
            except Exception:
                name = "NaN"
            infs["name"] = name

            try:
                year = lic.find("span", class_="lister-item-year text-muted unbold").text
            except Exception:
                year = "NaN"
            infs["year"] = year

            try:
                certificate = lic.find("span", class_="certificate").text
            except Exception:
                certificate = "NaN"
            infs["certificate"] = certificate

            try:
                runtime = lic.find("span", class_="runtime").text
            except Exception as e:
                runtime = "NaN"
            infs["runtime"] = runtime

            try:
                genre = lic.find("span", class_="genre").text
            except Exception:
                genre = "NaN"
            infs["genre"] = genre

            try:
                rating = lic.find("div", class_="inline-block ratings-imdb-rating").strong.text
            except Exception:
                rating = "NaN"
            infs["rating"] = rating

            try:
                metascore = lic.find("div", class_="inline-block ratings-metascore").text
            except Exception:
                metascore = "NaN"
            infs["metascore"] = metascore

            try:
                text_muted = lic.find_all("p", class_="text-muted")[1].text
            except Exception:
                text_muted = "NaN"
            infs["text-muted"] = text_muted
            
            try:
                l = np.array(lic.find_all("p")[2].text.split("\n"))
                i = argmax(l==['    Director:']*len(l))
                j = argmax(l==['    Stars:']*len(l))
                director = l[i+1:j]
                stars = l[j+1:]

            except Exception as e:
                print(e)
                director = "NaN"
                stars = "NaN"

            infs["director"] = director
            infs["stars"] = stars
            
            # print(votes)
            # print(director, stars)
            # print(number, name, year, certificate, runtime, genre, rating, metascore, text_muted)#director, stars)
            # break

            

        except Exception as e:
            print(e, "loop")
        
        # print(infs)
        page_infs += [infs]

except Exception as e:
    print(e,"whole")

page_infs = pd.DataFrame(page_infs)
page_infs.head()

# page_infs
# Out:
#   number                                        name    year   certificate  \
# 0     1.         The Dark Knight : Le Chevalier noir  (2008)  Tous publics
# 1     2.  Le Seigneur des anneaux : Le Retour du roi  (2003)  Tous publics
# 2     3.          Kill Bill: The Whole Bloody Affair  (2011)           NaN
# 3     4.                                   Inception  (2010)  Tous publics
# 4     5.    Le Seigneur des anneaux : Les Deux Tours  (2002)  Tous publics
#
#    runtime                                    genre rating  \
# 0  152 min       \nAction, Crime, Drama                9.0
# 1  201 min   \nAction, Adventure, Drama                9.0
# 2  247 min    \nAction, Crime, Thriller                8.8
# 3  148 min  \nAction, Adventure, Sci-Fi                8.8
# 4  179 min   \nAction, Adventure, Drama                8.8
#
#                                        metascore  \
# 0  \n84        \n        Metascore\n
# 1  \n94        \n        Metascore\n
# 2                                            NaN
# 3  \n74        \n        Metascore\n
# 4  \n87        \n        Metascore\n
#
#                                           text-muted                 director  \
# 0  \nWhen the menace known as the Joker wreaks ha...  [Christopher Nolan, | ]
# 1  \nGandalf and Aragorn lead the World of Men ag...      [Peter Jackson, | ]
# 2  \nThe Bride must kill her ex-boss and lover Bi...  [Quentin Tarantino, | ]
# 3  \nA thief who steals corporate secrets through...  [Christopher Nolan, | ]
# 4  \nWhile Frodo and Sam edge closer to Mordor wi...      [Peter Jackson, | ]
#
#                                                stars
# 0  [Christian Bale, , Heath Ledger, , Aaron Eckha...
# 1  [Elijah Wood, , Viggo Mortensen, , Ian McKelle...
# 2  [Uma Thurman, , Lucy Liu, , Vivica A. Fox, , M...
# 3  [Leonardo DiCaprio, , Joseph Gordon-Levitt, , ...
# 4  [Elijah Wood, , Ian McKellen, , Viggo Mortense...

# %% [markdown]
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=100&explore=genres&ref_=adv_nxt

# %%
def getPageN(start):

    page_infs = []

    try:
        url = f"https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start={start}&explore=genres&ref_=adv_nxt"
        source = requests.get(url)
        print(url)
        # source = requests.get("https://www.imdb.com/search/title/?title_type=movie&genres=action&start={start}&explore=title_type,genres&ref_=adv_nxt")
        
        source.raise_for_status()

        soup = BeautifulSoup(source.text, "html.parser")
        
        movies = soup.find('div', class_ = "lister-list").find_all("div",class_="lister-item mode-advanced")

        for movie in movies:

            infs = {}

            try:

                lic = movie.find("div", class_="lister-item-content")

                try:
                    number = lic.find("span", class_="lister-item-index unbold text-primary").text
                except Exception:
                    number = "NaN"
                infs["number"] = number

                try:
                    name = lic.a.text
                except Exception:
                    name = "NaN"
                infs["name"] = name

                try:
                    year = lic.find("span", class_="lister-item-year text-muted unbold").text
                except Exception:
                    year = "NaN"
                infs["year"] = year

                try:
                    certificate = lic.find("span", class_="certificate").text
                except Exception:
                    certificate = "NaN"
                infs["certificate"] = certificate

                try:
                    runtime = lic.find("span", class_="runtime").text
                except Exception as e:
                    runtime = "NaN"
                infs["runtime"] = runtime

                try:
                    genre = lic.find("span", class_="genre").text
                except Exception:
                    genre = "NaN"
                infs["genre"] = genre

                try:
                    rating = lic.find("div", class_="inline-block ratings-imdb-rating").strong.text
                except Exception:
                    rating = "NaN"
                infs["rating"] = rating

                try:
                    metascore = lic.find("div", class_="inline-block ratings-metascore").text
                except Exception:
                    metascore = "NaN"
                infs["metascore"] = metascore

                try:
                    text_muted = lic.find_all("p", class_="text-muted")[1].text
                except Exception:
                    text_muted = "NaN"
                infs["text-muted"] = text_muted
                
                try:
                    l = np.array(lic.find_all("p")[2].text.split("\n"))
                    i = argmax(l==['    Director:']*len(l))
                    j = argmax(l==['    Stars:']*len(l))
                    director = l[i+1:j]
                    stars = l[j+1:]

                except Exception as e:
                    # print(e)
                    director = "NaN"
                    stars = "NaN"

                infs["director"] = director
                infs["stars"] = stars
                                

            except Exception as e:
                print(e, "loop")
            
            # print(infs)
            page_infs += [infs]

    except Exception as e:
        print(e,"whole")

    return page_infs

# page_infs

# %%
import re

# %%
def cleanPage(films):
    
    films.drop('number', axis = 1, inplace=True)
    
    films['year'] = films["year"].apply(lambda x : x[1:-1] )
    
    films['runtime'] = films['runtime'].apply(lambda x : int(x.split(" ")[0]))
    films = films.astype({'runtime':'int'})
    
    films['genre'] = films['genre'].apply(lambda x : x[2:])
    films['genre'] = films['genre'].apply(lambda x : [g for g in x.split(',')])

    films = films.astype({'rating':'float'})

    films['metascore'] = films['metascore'].apply(lambda x : int(re.search(r'\d+', x).group()) if re.search(r'\d+', x) != None else -1)

    films["text-muted"] = films["text-muted"].apply(lambda x: x[1:])

    films["director"] = films["director"].apply(lambda x : [ d if d != '| ' else None for d in x] )
    # films["director"] = films["director"].apply(lambda x : x.remove(None))

    films["stars"] = films["stars"].apply(lambda x : [s.split(',') for s in x])
    films["stars"] = films["stars"].apply(lambda x : [s[0] for s in x[:-1]])

    return films

# %%
cleanPage(page_infs)
# Out:
#                                                  name      year  \
# 0                 The Dark Knight : Le Chevalier noir      2008
# 1          Le Seigneur des anneaux : Le Retour du roi      2003
# 2                  Kill Bill: The Whole Bloody Affair      2011
# 3                                           Inception      2010
# 4            Le Seigneur des anneaux : Les Deux Tours      2002
# 5   Le Seigneur des anneaux : La Communauté de l'a...      2001
# 6                                              Matrix      1999
# 7                             L'Empire contre-attaque      1980
# 8                  Terminator 2 : Le jugement dernier      1991
# 9                               La guerre des étoiles      1977
# 10                                          Gladiator      2000
# 11                                               Léon      1994
# 12                         Spider-Man: New Generation      2018
# 13                                  Avengers: Endgame      2019
# 14                             Avengers: Infinity War      2018
# 15                                  Top Gun: Maverick      2022
# 16                              The Dark Knight Rises      2012
# 17                                       Black Friday      2004
# 18                                 Aliens : Le Retour      1986
# 19                  Les Aventuriers de l'arche perdue      1981
# 20                                             Dangal      2016
# 21                            Spider-Man: No Way Home      2021
# 22                                               Heat      1995
# 23                                  Le Retour du Jedi      1983
# 24                               La mort aux trousses      1959
# 25                                               1917      2019
# 26                                            Warrior      2011
# 27                                    V pour vendetta      2005
# 28                                      Batman Begins      2005
# 29                                Kill Bill: Volume I      2003
# 30                      Arnaques, crimes et botanique      1998
# 31                                      Jurassic Park      1993
# 32              Indiana Jones et la dernière croisade      1989
# 33                                   Piège de cristal      1988
# 34                           Le mécano de la Générale      1926
# 35                                    Sherlock Junior      1924
# 36                  Everything Everywhere All at Once      2022
# 37                                              Logan      2017
# 38                                               Rush  I) (2013
# 39                                        Le Mans '66      2019
# 40                                 Mad Max: Fury Road      2015
# 41                                            Dragons      2010
# 42  Pirates des Caraïbes : La malédiction du Black...      2003
# 43                                    Le géant de fer      1999
# 44                                         Terminator      1984
# 45                                       Blade Runner      1982
# 46                                  L'enfer est à lui      1949
# 47                                   Monte là-dessus!      1923
# 48                                                RRR      2022
# 49                         Les Gardiens de la Galaxie      2014
#
#                         certificate  runtime  \
# 0                      Tous publics      152
# 1                      Tous publics      201
# 2                               NaN      247
# 3                      Tous publics      148
# 4                      Tous publics      179
# 5                      Tous publics      178
# 6   Tous publics avec avertissement      136
# 7                      Tous publics      124
# 8                                12      137
# 9                      Tous publics      121
# 10  Tous publics avec avertissement      155
# 11                               12      110
# 12                     Tous publics      117
# 13                     Tous publics      181
# 14                     Tous publics      149
# 15                     Tous publics      130
# 16                     Tous publics      164
# 17                              NaN      143
# 18                               13      137
# 19                     Tous publics      115
# 20                     Tous publics      161
# 21                     Tous publics      148
# 22  Tous publics avec avertissement      170
# 23                     Tous publics      131
# 24                     Tous publics      136
# 25  Tous publics avec avertissement      119
# 26                     Tous publics      140
# 27  Tous publics avec avertissement      132
# 28                     Tous publics      140
# 29                               16      111
# 30                     Tous publics      107
# 31                     Tous publics      127
# 32                     Tous publics      127
# 33                     Tous publics      132
# 34                     Tous publics       67
# 35                     Tous publics       45
# 36                     Tous publics      139
# 37            12 avec avertissement      137
# 38                     Tous publics      123
# 39                     Tous publics      152
# 40  Tous publics avec avertissement      120
# 41                     Tous publics       98
# 42                     Tous publics      143
# 43                     Tous publics       86
# 44                               13      107
# 45  Tous publics avec avertissement      117
# 46                               16      114
# 47                     Tous publics       74
# 48                     Tous publics      187
# 49                     Tous publics      121
#
#                                           genre  rating  metascore  \
# 0           [ction,  Crime,  Drama            ]     9.0         84
# 1       [ction,  Adventure,  Drama            ]     9.0         94
# 2        [ction,  Crime,  Thriller            ]     8.8         -1
# 3      [ction,  Adventure,  Sci-Fi            ]     8.8         74
# 4       [ction,  Adventure,  Drama            ]     8.8         87
# 5       [ction,  Adventure,  Drama            ]     8.8         92
# 6                  [ction,  Sci-Fi            ]     8.7         73
# 7     [ction,  Adventure,  Fantasy            ]     8.7         82
# 8                  [ction,  Sci-Fi            ]     8.6         75
# 9     [ction,  Adventure,  Fantasy            ]     8.6         90
# 10      [ction,  Adventure,  Drama            ]     8.5         67
# 11          [ction,  Crime,  Drama            ]     8.5         64
# 12  [nimation,  Action,  Adventure            ]     8.4         87
# 13      [ction,  Adventure,  Drama            ]     8.4         78
# 14     [ction,  Adventure,  Sci-Fi            ]     8.4         68
# 15                  [ction,  Drama            ]     8.4         78
# 16                  [ction,  Drama            ]     8.4         78
# 17          [ction,  Crime,  Drama            ]     8.4         76
# 18     [ction,  Adventure,  Sci-Fi            ]     8.4         84
# 19              [ction,  Adventure            ]     8.4         85
# 20      [ction,  Biography,  Drama            ]     8.3         -1
# 21    [ction,  Adventure,  Fantasy            ]     8.3         71
# 22          [ction,  Crime,  Drama            ]     8.3         76
# 23    [ction,  Adventure,  Fantasy            ]     8.3         58
# 24    [ction,  Adventure,  Mystery            ]     8.3         98
# 25            [ction,  Drama,  War            ]     8.2         78
# 26          [ction,  Drama,  Sport            ]     8.2         71
# 27         [ction,  Drama,  Sci-Fi            ]     8.2         62
# 28          [ction,  Crime,  Drama            ]     8.2         70
# 29          [ction,  Crime,  Drama            ]     8.2         69
# 30         [ction,  Comedy,  Crime            ]     8.2         66
# 31     [ction,  Adventure,  Sci-Fi            ]     8.2         68
# 32              [ction,  Adventure            ]     8.2         65
# 33               [ction,  Thriller            ]     8.2         72
# 34     [ction,  Adventure,  Comedy            ]     8.2         -1
# 35       [ction,  Comedy,  Romance            ]     8.2         -1
# 36     [ction,  Adventure,  Comedy            ]     8.1         81
# 37         [ction,  Drama,  Sci-Fi            ]     8.1         77
# 38      [ction,  Biography,  Drama            ]     8.1         74
# 39      [ction,  Biography,  Drama            ]     8.1         81
# 40     [ction,  Adventure,  Sci-Fi            ]     8.1         90
# 41  [nimation,  Action,  Adventure            ]     8.1         75
# 42    [ction,  Adventure,  Fantasy            ]     8.1         63
# 43  [nimation,  Action,  Adventure            ]     8.1         85
# 44                 [ction,  Sci-Fi            ]     8.1         84
# 45         [ction,  Drama,  Sci-Fi            ]     8.1         84
# 46          [ction,  Crime,  Drama            ]     8.1         -1
# 47      [ction,  Comedy,  Thriller            ]     8.1         -1
# 48                  [ction,  Drama            ]     8.0         83
# 49     [ction,  Adventure,  Comedy            ]     8.0         76
#
#                                            text-muted  \
# 0   When the menace known as the Joker wreaks havo...
# 1   Gandalf and Aragorn lead the World of Men agai...
# 2   The Bride must kill her ex-boss and lover Bill...
# 3   A thief who steals corporate secrets through t...
# 4   While Frodo and Sam edge closer to Mordor with...
# 5   A meek Hobbit from the Shire and eight compani...
# 6   When a beautiful stranger leads computer hacke...
# 7   After the Rebels are brutally overpowered by t...
# 8   A cyborg, identical to the one who failed to k...
# 9   Luke Skywalker joins forces with a Jedi Knight...
# 10  A former Roman General sets out to exact venge...
# 11  12-year-old Mathilda is reluctantly taken in b...
# 12  Teen Miles Morales becomes the Spider-Man of h...
# 13  After the devastating events of Avengers: Infi...
# 14  The Avengers and their allies must be willing ...
# 15  After thirty years, Maverick is still pushing ...
# 16  Eight years after the Joker's reign of anarchy...
# 17  A film about the investigations following the ...
# 18  Fifty-seven years after surviving an apocalypt...
# 19  Archaeology professor Indiana Jones ventures t...
# 20  Former wrestler Mahavir Singh Phogat and his t...
# 21  With Spider-Man's identity now revealed, Peter...
# 22  A group of high-end professional thieves start...
# 23  After a daring mission to rescue Han Solo from...
# 24  A New York City advertising executive goes on ...
# 25  April 6th, 1917. As an infantry battalion asse...
# 26  The youngest son of an alcoholic former boxer ...
# 27  In a future British dystopian society, a shado...
# 28  After training with his mentor, Batman begins ...
# 29  After awakening from a four-year coma, a forme...
# 30  Eddy persuades his three pals to pool money fo...
# 31  A pragmatic paleontologist touring an almost c...
# 32  In 1938, after his father Professor Henry Jone...
# 33  An NYPD officer tries to save his wife and sev...
# 34  After being rejected by the Confederate milita...
# 35  A film projectionist longs to be a detective, ...
# 36  An aging Chinese immigrant is swept up in an i...
# 37  In a future where mutants are nearly extinct, ...
# 38  The merciless 1970s rivalry between Formula On...
# 39  American car designer Carroll Shelby and drive...
# 40  In a post-apocalyptic wasteland, a woman rebel...
# 41  A hapless young Viking who aspires to hunt dra...
# 42  Blacksmith Will Turner teams up with eccentric...
# 43  A young boy befriends a giant robot from outer...
# 44  A human soldier is sent from 2029 to 1984 to s...
# 45  A blade runner must pursue and terminate four ...
# 46  A psychopathic criminal with a mother complex ...
# 47  A boy leaves his small country town and heads ...
# 48  A fictitious story about two legendary revolut...
# 49  A group of intergalactic criminals must pull t...
#
#                                              director  \
# 0                           [Christopher Nolan, None]
# 1                               [Peter Jackson, None]
# 2                           [Quentin Tarantino, None]
# 3                           [Christopher Nolan, None]
# 4                               [Peter Jackson, None]
# 5                               [Peter Jackson, None]
# 6   [    Directors:, Lana Wachowski, , Lilly Wacho...
# 7                              [Irvin Kershner, None]
# 8                               [James Cameron, None]
# 9                                [George Lucas, None]
# 10                               [Ridley Scott, None]
# 11                                 [Luc Besson, None]
# 12  [    Directors:, Bob Persichetti, , Peter Rams...
# 13  [    Directors:, Anthony Russo, , Joe Russo, N...
# 14  [    Directors:, Anthony Russo, , Joe Russo, N...
# 15                            [Joseph Kosinski, None]
# 16                          [Christopher Nolan, None]
# 17                             [Anurag Kashyap, None]
# 18                              [James Cameron, None]
# 19                           [Steven Spielberg, None]
# 20                              [Nitesh Tiwari, None]
# 21                                  [Jon Watts, None]
# 22                               [Michael Mann, None]
# 23                           [Richard Marquand, None]
# 24                           [Alfred Hitchcock, None]
# 25                                 [Sam Mendes, None]
# 26                             [Gavin O'Connor, None]
# 27                             [James McTeigue, None]
# 28                          [Christopher Nolan, None]
# 29                          [Quentin Tarantino, None]
# 30                                [Guy Ritchie, None]
# 31                           [Steven Spielberg, None]
# 32                           [Steven Spielberg, None]
# 33                             [John McTiernan, None]
# 34  [    Directors:, Clyde Bruckman, , Buster Keat...
# 35                              [Buster Keaton, None]
# 36  [    Directors:, Dan Kwan, , Daniel Scheinert,...
# 37                              [James Mangold, None]
# 38                                 [Ron Howard, None]
# 39                              [James Mangold, None]
# 40                              [George Miller, None]
# 41  [    Directors:, Dean DeBlois, , Chris Sanders...
# 42                             [Gore Verbinski, None]
# 43                                  [Brad Bird, None]
# 44                              [James Cameron, None]
# 45                               [Ridley Scott, None]
# 46                                [Raoul Walsh, None]
# 47  [    Directors:, Fred C. Newmeyer, , Sam Taylo...
# 48                             [S.S. Rajamouli, None]
# 49                                 [James Gunn, None]
#
#                                                 stars
# 0   [Christian Bale, Heath Ledger, Aaron Eckhart, ...
# 1   [Elijah Wood, Viggo Mortensen, Ian McKellen, O...
# 2   [Uma Thurman, Lucy Liu, Vivica A. Fox, Michael...
# 3   [Leonardo DiCaprio, Joseph Gordon-Levitt, Elli...
# 4   [Elijah Wood, Ian McKellen, Viggo Mortensen, O...
# 5   [Elijah Wood, Ian McKellen, Orlando Bloom, Sea...
# 6   [Keanu Reeves, Laurence Fishburne, Carrie-Anne...
# 7   [Mark Hamill, Harrison Ford, Carrie Fisher, Bi...
# 8   [Arnold Schwarzenegger, Linda Hamilton, Edward...
# 9   [Mark Hamill, Harrison Ford, Carrie Fisher, Al...
# 10  [Russell Crowe, Joaquin Phoenix, Connie Nielse...
# 11  [Jean Reno, Gary Oldman, Natalie Portman, Dann...
# 12  [Shameik Moore, Jake Johnson, Hailee Steinfeld...
# 13  [Robert Downey Jr., Chris Evans, Mark Ruffalo,...
# 14  [Robert Downey Jr., Chris Hemsworth, Mark Ruff...
# 15  [Tom Cruise, Jennifer Connelly, Miles Teller, ...
# 16  [Christian Bale, Tom Hardy, Anne Hathaway, Gar...
# 17  [Kay Kay Menon, Pawan Malhotra, Aditya Srivast...
# 18  [Sigourney Weaver, Michael Biehn, Carrie Henn,...
# 19  [Harrison Ford, Karen Allen, Paul Freeman, Joh...
# 20  [Aamir Khan, Sakshi Tanwar, Fatima Sana Shaikh...
# 21  [Tom Holland, Zendaya, Benedict Cumberbatch, J...
# 22  [Al Pacino, Robert De Niro, Val Kilmer, Jon Vo...
# 23  [Mark Hamill, Harrison Ford, Carrie Fisher, Bi...
# 24  [Cary Grant, Eva Marie Saint, James Mason, Jes...
# 25  [Dean-Charles Chapman, George MacKay, Daniel M...
# 26  [Tom Hardy, Nick Nolte, Joel Edgerton, Jennife...
# 27  [Hugo Weaving, Natalie Portman, Rupert Graves,...
# 28  [Christian Bale, Michael Caine, Ken Watanabe, ...
# 29  [Uma Thurman, David Carradine, Daryl Hannah, M...
# 30  [Jason Flemyng, Dexter Fletcher, Nick Moran, J...
# 31  [Sam Neill, Laura Dern, Jeff Goldblum, Richard...
# 32  [Harrison Ford, Sean Connery, Alison Doody, De...
# 33  [Bruce Willis, Alan Rickman, Bonnie Bedelia, R...
# 34  [Buster Keaton, Marion Mack, Glen Cavender, Ji...
# 35  [Buster Keaton, Kathryn McGuire, Joe Keaton, E...
# 36  [Michelle Yeoh, Stephanie Hsu, Jamie Lee Curti...
# 37  [Hugh Jackman, Patrick Stewart, Dafne Keen, Bo...
# 38  [Daniel Brühl, Chris Hemsworth, Olivia Wilde, ...
# 39  [Matt Damon, Christian Bale, Jon Bernthal, Cai...
# 40  [Tom Hardy, Charlize Theron, Nicholas Hoult, Z...
# 41  [Jay Baruchel, Gerard Butler, Christopher Mint...
# 42  [Johnny Depp, Geoffrey Rush, Orlando Bloom, Ke...
# 43  [Eli Marienthal, Harry Connick Jr., Jennifer A...
# 44  [Arnold Schwarzenegger, Linda Hamilton, Michae...
# 45  [Harrison Ford, Rutger Hauer, Sean Young, Edwa...
# 46  [James Cagney, Virginia Mayo, Edmond O'Brien, ...
# 47  [Harold Lloyd, Mildred Davis, Bill Strother, N...
# 48  [N.T. Rama Rao Jr., Ram Charan Teja, Ajay Devg...
# 49  [Chris Pratt, Vin Diesel, Bradley Cooper, Zoe ...

# %%
#collect over all pages
df = []
n_start = 1
n_end = 2088
step = 50
ite = int(np.ceil((n_end-n_start)/step))

# df = cleanPage(pd.DataFrame(getPageN(1)))

for i in range(ite):
    page = getPageN(n_start+i*step)
    # df_page = pd.DataFrame(page)
    # df_clean_page = cleanPage(df_page)
    
    # print(df_clean_page.iloc[0])

    df += [page]

    print(n_start+i*step)

# df.shape
df
# Out:
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1&explore=genres&ref_=adv_nxt
# 1
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=51&explore=genres&ref_=adv_nxt
# 51
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=101&explore=genres&ref_=adv_nxt
# 101
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=151&explore=genres&ref_=adv_nxt
# 151
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=201&explore=genres&ref_=adv_nxt
# 201
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=251&explore=genres&ref_=adv_nxt
# 251
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=301&explore=genres&ref_=adv_nxt
# 301
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=351&explore=genres&ref_=adv_nxt
# 351
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=401&explore=genres&ref_=adv_nxt
# 401
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=451&explore=genres&ref_=adv_nxt
# 451
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=501&explore=genres&ref_=adv_nxt
# 501
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=551&explore=genres&ref_=adv_nxt
# 551
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=601&explore=genres&ref_=adv_nxt
# 601
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=651&explore=genres&ref_=adv_nxt
# 651
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=701&explore=genres&ref_=adv_nxt
# 701
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=751&explore=genres&ref_=adv_nxt
# 751
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=801&explore=genres&ref_=adv_nxt
# 801
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=851&explore=genres&ref_=adv_nxt
# 851
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=901&explore=genres&ref_=adv_nxt
# 901
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=951&explore=genres&ref_=adv_nxt
# 951
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1001&explore=genres&ref_=adv_nxt
# 1001
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1051&explore=genres&ref_=adv_nxt
# 1051
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1101&explore=genres&ref_=adv_nxt
# 1101
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1151&explore=genres&ref_=adv_nxt
# 1151
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1201&explore=genres&ref_=adv_nxt
# 1201
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1251&explore=genres&ref_=adv_nxt
# 1251
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1301&explore=genres&ref_=adv_nxt
# 1301
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1351&explore=genres&ref_=adv_nxt
# 1351
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1401&explore=genres&ref_=adv_nxt
# 1401
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1451&explore=genres&ref_=adv_nxt
# 1451
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1501&explore=genres&ref_=adv_nxt
# 1501
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1551&explore=genres&ref_=adv_nxt
# 1551
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1601&explore=genres&ref_=adv_nxt
# 1601
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1651&explore=genres&ref_=adv_nxt
# 1651
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1701&explore=genres&ref_=adv_nxt
# 1701
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1751&explore=genres&ref_=adv_nxt
# 1751
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1801&explore=genres&ref_=adv_nxt
# 1801
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1851&explore=genres&ref_=adv_nxt
# 1851
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1901&explore=genres&ref_=adv_nxt
# 1901
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=1951&explore=genres&ref_=adv_nxt
# 1951
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=2001&explore=genres&ref_=adv_nxt
# 2001
# https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&genres=action&languages=en&sort=user_rating,desc&start=2051&explore=genres&ref_=adv_nxt
# 2051
# [[{'number': '1.',
#    'name': 'The Dark Knight : Le Chevalier noir',
#    'year': '(2008)',
#    'certificate': 'Tous publics',
#    'runtime': '152 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '9.0',
#    'metascore': '\n84        \n        Metascore\n            ',
#    'text-muted': '\nWhen the menace known as the Joker wreaks havoc and chaos on the people of Gotham, Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.',
#    'director': array(['Christopher Nolan', '| '], dtype='<U17'),
#    'stars': array(['Christian Bale, ', 'Heath Ledger, ', 'Aaron Eckhart, ',
#           'Michael Caine', ''], dtype='<U17')},
#   {'number': '2.',
#    'name': 'Le Seigneur des anneaux : Le Retour du roi',
#    'year': '(2003)',
#    'certificate': 'Tous publics',
#    'runtime': '201 min',
#    'genre': '\nAction, Adventure, Drama            ',
#    'rating': '9.0',
#    'metascore': '\n94        \n        Metascore\n            ',
#    'text-muted': "\nGandalf and Aragorn lead the World of Men against Sauron's army to draw his gaze from Frodo and Sam as they approach Mount Doom with the One Ring.",
#    'director': array(['Peter Jackson', '| '], dtype='<U17'),
#    'stars': array(['Elijah Wood, ', 'Viggo Mortensen, ', 'Ian McKellen, ',
#           'Orlando Bloom', ''], dtype='<U17')},
#   {'number': '3.',
#    'name': 'Kill Bill: The Whole Bloody Affair',
#    'year': '(2011)',
#    'certificate': 'NaN',
#    'runtime': '247 min',
#    'genre': '\nAction, Crime, Thriller            ',
#    'rating': '8.8',
#    'metascore': 'NaN',
#    'text-muted': '\nThe Bride must kill her ex-boss and lover Bill who betrayed her at her wedding rehearsal, shot her in the head and took away her unborn daughter. But first, she must make the other four members of the Deadly Viper Assassination Squad suffer.',
#    'director': array(['Quentin Tarantino', '| '], dtype='<U17'),
#    'stars': array(['Uma Thurman, ', 'Lucy Liu, ', 'Vivica A. Fox, ', 'Michael Madsen',
#           ''], dtype='<U17')},
#   {'number': '4.',
#    'name': 'Inception',
#    'year': '(2010)',
#    'certificate': 'Tous publics',
#    'runtime': '148 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '8.8',
#    'metascore': '\n74        \n        Metascore\n            ',
#    'text-muted': '\nA thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.',
#    'director': array(['Christopher Nolan', '| '], dtype='<U22'),
#    'stars': array(['Leonardo DiCaprio, ', 'Joseph Gordon-Levitt, ', 'Elliot Page, ',
#           'Ken Watanabe', ''], dtype='<U22')},
#   {'number': '5.',
#    'name': 'Le Seigneur des anneaux : Les Deux Tours',
#    'year': '(2002)',
#    'certificate': 'Tous publics',
#    'runtime': '179 min',
#    'genre': '\nAction, Adventure, Drama            ',
#    'rating': '8.8',
#    'metascore': '\n87        \n        Metascore\n            ',
#    'text-muted': "\nWhile Frodo and Sam edge closer to Mordor with the help of the shifty Gollum, the divided fellowship makes a stand against Sauron's new ally, Saruman, and his hordes of Isengard.",
#    'director': array(['Peter Jackson', '| '], dtype='<U17'),
#    'stars': array(['Elijah Wood, ', 'Ian McKellen, ', 'Viggo Mortensen, ',
#           'Orlando Bloom', ''], dtype='<U17')},
#   {'number': '6.',
#    'name': "Le Seigneur des anneaux : La Communauté de l'anneau",
#    'year': '(2001)',
#    'certificate': 'Tous publics',
#    'runtime': '178 min',
#    'genre': '\nAction, Adventure, Drama            ',
#    'rating': '8.8',
#    'metascore': '\n92        \n        Metascore\n            ',
#    'text-muted': '\nA meek Hobbit from the Shire and eight companions set out on a journey to destroy the powerful One Ring and save Middle-earth from the Dark Lord Sauron.',
#    'director': array(['Peter Jackson', '| '], dtype='<U15'),
#    'stars': array(['Elijah Wood, ', 'Ian McKellen, ', 'Orlando Bloom, ', 'Sean Bean',
#           ''], dtype='<U15')},
#   {'number': '7.',
#    'name': 'Matrix',
#    'year': '(1999)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '136 min',
#    'genre': '\nAction, Sci-Fi            ',
#    'rating': '8.7',
#    'metascore': '\n73        \n        Metascore\n            ',
#    'text-muted': '\nWhen a beautiful stranger leads computer hacker Neo to a forbidding underworld, he discovers the shocking truth--the life he knows is the elaborate deception of an evil cyber-intelligence.',
#    'director': array(['    Directors:', 'Lana Wachowski, ', 'Lilly Wachowski', '| '],
#          dtype='<U20'),
#    'stars': array(['Keanu Reeves, ', 'Laurence Fishburne, ', 'Carrie-Anne Moss, ',
#           'Hugo Weaving', ''], dtype='<U20')},
#   {'number': '8.',
#    'name': "L'Empire contre-attaque",
#    'year': '(1980)',
#    'certificate': 'Tous publics',
#    'runtime': '124 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '8.7',
#    'metascore': '\n82        \n        Metascore\n            ',
#    'text-muted': '\nAfter the Rebels are brutally overpowered by the Empire on the ice planet Hoth, Luke Skywalker begins Jedi training with Yoda, while his friends are pursued across the galaxy by Darth Vader and bounty hunter Boba Fett.',
#    'director': array(['Irvin Kershner', '| '], dtype='<U18'),
#    'stars': array(['Mark Hamill, ', 'Harrison Ford, ', 'Carrie Fisher, ',
#           'Billy Dee Williams', ''], dtype='<U18')},
#   {'number': '9.',
#    'name': 'Terminator 2 : Le jugement dernier',
#    'year': '(1991)',
#    'certificate': '12',
#    'runtime': '137 min',
#    'genre': '\nAction, Sci-Fi            ',
#    'rating': '8.6',
#    'metascore': '\n75        \n        Metascore\n            ',
#    'text-muted': '\nA cyborg, identical to the one who failed to kill Sarah Connor, must now protect her ten-year-old son John from a more advanced and powerful cyborg.',
#    'director': array(['James Cameron', '| '], dtype='<U23'),
#    'stars': array(['Arnold Schwarzenegger, ', 'Linda Hamilton, ', 'Edward Furlong, ',
#           'Robert Patrick', ''], dtype='<U23')},
#   {'number': '10.',
#    'name': 'La guerre des étoiles',
#    'year': '(1977)',
#    'certificate': 'Tous publics',
#    'runtime': '121 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '8.6',
#    'metascore': '\n90        \n        Metascore\n            ',
#    'text-muted': "\nLuke Skywalker joins forces with a Jedi Knight, a cocky pilot, a Wookiee and two droids to save the galaxy from the Empire's world-destroying battle station, while also attempting to rescue Princess Leia from the mysterious Darth Vader.",
#    'director': array(['George Lucas', '| '], dtype='<U15'),
#    'stars': array(['Mark Hamill, ', 'Harrison Ford, ', 'Carrie Fisher, ',
#           'Alec Guinness', ''], dtype='<U15')},
#   {'number': '11.',
#    'name': 'Gladiator',
#    'year': '(2000)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '155 min',
#    'genre': '\nAction, Adventure, Drama            ',
#    'rating': '8.5',
#    'metascore': '\n67        \n        Metascore\n            ',
#    'text-muted': '\nA former Roman General sets out to exact vengeance against the corrupt emperor who murdered his family and sent him into slavery.',
#    'director': array(['Ridley Scott', '| '], dtype='<U17'),
#    'stars': array(['Russell Crowe, ', 'Joaquin Phoenix, ', 'Connie Nielsen, ',
#           'Oliver Reed', ''], dtype='<U17')},
#   {'number': '12.',
#    'name': 'Léon',
#    'year': '(1994)',
#    'certificate': '12',
#    'runtime': '110 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.5',
#    'metascore': '\n64        \n        Metascore\n            ',
#    'text-muted': "\n12-year-old Mathilda is reluctantly taken in by Léon, a professional assassin, after her family is murdered. An unusual relationship forms as she becomes his protégée and learns the assassin's trade.",
#    'director': array(['Luc Besson', '| '], dtype='<U17'),
#    'stars': array(['Jean Reno, ', 'Gary Oldman, ', 'Natalie Portman, ',
#           'Danny Aiello', ''], dtype='<U17')},
#   {'number': '13.',
#    'name': 'Spider-Man: New Generation',
#    'year': '(2018)',
#    'certificate': 'Tous publics',
#    'runtime': '117 min',
#    'genre': '\nAnimation, Action, Adventure            ',
#    'rating': '8.4',
#    'metascore': '\n87        \n        Metascore\n            ',
#    'text-muted': '\nTeen Miles Morales becomes the Spider-Man of his universe, and must join with five spider-powered individuals from other dimensions to stop a threat for all realities.',
#    'director': array(['    Directors:', 'Bob Persichetti, ', 'Peter Ramsey, ',
#           'Rodney Rothman', '| '], dtype='<U18'),
#    'stars': array(['Shameik Moore, ', 'Jake Johnson, ', 'Hailee Steinfeld, ',
#           'Mahershala Ali', ''], dtype='<U18')},
#   {'number': '14.',
#    'name': 'Avengers: Endgame',
#    'year': '(2019)',
#    'certificate': 'Tous publics',
#    'runtime': '181 min',
#    'genre': '\nAction, Adventure, Drama            ',
#    'rating': '8.4',
#    'metascore': '\n78        \n        Metascore\n            ',
#    'text-muted': "\nAfter the devastating events of Avengers: Infinity War (2018), the universe is in ruins. With the help of remaining allies, the Avengers assemble once more in order to reverse Thanos' actions and restore balance to the universe.",
#    'director': array(['    Directors:', 'Anthony Russo, ', 'Joe Russo', '| '],
#          dtype='<U19'),
#    'stars': array(['Robert Downey Jr., ', 'Chris Evans, ', 'Mark Ruffalo, ',
#           'Chris Hemsworth', ''], dtype='<U19')},
#   {'number': '15.',
#    'name': 'Avengers: Infinity War',
#    'year': '(2018)',
#    'certificate': 'Tous publics',
#    'runtime': '149 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '8.4',
#    'metascore': '\n68        \n        Metascore\n            ',
#    'text-muted': '\nThe Avengers and their allies must be willing to sacrifice all in an attempt to defeat the powerful Thanos before his blitz of devastation and ruin puts an end to the universe.',
#    'director': array(['    Directors:', 'Anthony Russo, ', 'Joe Russo', '| '],
#          dtype='<U19'),
#    'stars': array(['Robert Downey Jr., ', 'Chris Hemsworth, ', 'Mark Ruffalo, ',
#           'Chris Evans', ''], dtype='<U19')},
#   {'number': '16.',
#    'name': 'Top Gun: Maverick',
#    'year': '(2022)',
#    'certificate': 'Tous publics',
#    'runtime': '130 min',
#    'genre': '\nAction, Drama            ',
#    'rating': '8.4',
#    'metascore': '\n78        \n        Metascore\n            ',
#    'text-muted': "\nAfter thirty years, Maverick is still pushing the envelope as a top naval aviator, but must confront ghosts of his past when he leads TOP GUN's elite graduates on a mission that demands the ultimate sacrifice from those chosen to fly it.",
#    'director': array(['Joseph Kosinski', '| '], dtype='<U19'),
#    'stars': array(['Tom Cruise, ', 'Jennifer Connelly, ', 'Miles Teller, ',
#           'Val Kilmer', ''], dtype='<U19')},
#   {'number': '17.',
#    'name': 'The Dark Knight Rises',
#    'year': '(2012)',
#    'certificate': 'Tous publics',
#    'runtime': '164 min',
#    'genre': '\nAction, Drama            ',
#    'rating': '8.4',
#    'metascore': '\n78        \n        Metascore\n            ',
#    'text-muted': "\nEight years after the Joker's reign of anarchy, Batman, with the help of the enigmatic Selina Kyle, is forced from his exile to save Gotham City from the brutal guerrilla terrorist Bane.",
#    'director': array(['Christopher Nolan', '| '], dtype='<U17'),
#    'stars': array(['Christian Bale, ', 'Tom Hardy, ', 'Anne Hathaway, ',
#           'Gary Oldman', ''], dtype='<U17')},
#   {'number': '18.',
#    'name': 'Black Friday',
#    'year': '(2004)',
#    'certificate': 'NaN',
#    'runtime': '143 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.4',
#    'metascore': '\n76        \n        Metascore\n            ',
#    'text-muted': '\nA film about the investigations following the 1993 serial Bombay bomb blasts, told through the different stories of the people involved --police, conspirators, victims, middlemen.',
#    'director': array(['Anurag Kashyap', '| '], dtype='<U21'),
#    'stars': array(['Kay Kay Menon, ', 'Pawan Malhotra, ', 'Aditya Srivastav, ',
#           'Dibyendu Bhattacharya', ''], dtype='<U21')},
#   {'number': '19.',
#    'name': 'Aliens : Le Retour',
#    'year': '(1986)',
#    'certificate': '13',
#    'runtime': '137 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '8.4',
#    'metascore': '\n84        \n        Metascore\n            ',
#    'text-muted': '\nFifty-seven years after surviving an apocalyptic attack aboard her space vessel by merciless space creatures, Officer Ripley awakens from hyper-sleep and tries to warn anyone who will listen about the predators.',
#    'director': array(['James Cameron', '| '], dtype='<U18'),
#    'stars': array(['Sigourney Weaver, ', 'Michael Biehn, ', 'Carrie Henn, ',
#           'Paul Reiser', ''], dtype='<U18')},
#   {'number': '20.',
#    'name': "Les Aventuriers de l'arche perdue",
#    'year': '(1981)',
#    'certificate': 'Tous publics',
#    'runtime': '115 min',
#    'genre': '\nAction, Adventure            ',
#    'rating': '8.4',
#    'metascore': '\n85        \n        Metascore\n            ',
#    'text-muted': '\nArchaeology professor Indiana Jones ventures to seize a biblical artefact known as the Ark of the Covenant. While doing so, he puts up a fight against Renee and a troop of Nazis.',
#    'director': array(['Steven Spielberg', '| '], dtype='<U16'),
#    'stars': array(['Harrison Ford, ', 'Karen Allen, ', 'Paul Freeman, ',
#           'John Rhys-Davies', ''], dtype='<U16')},
#   {'number': '21.',
#    'name': 'Dangal',
#    'year': '(2016)',
#    'certificate': 'Tous publics',
#    'runtime': '161 min',
#    'genre': '\nAction, Biography, Drama            ',
#    'rating': '8.3',
#    'metascore': 'NaN',
#    'text-muted': '\nFormer wrestler Mahavir Singh Phogat and his two wrestler daughters struggle towards glory at the Commonwealth Games in the face of societal oppression.',
#    'director': array(['Nitesh Tiwari', '| '], dtype='<U20'),
#    'stars': array(['Aamir Khan, ', 'Sakshi Tanwar, ', 'Fatima Sana Shaikh, ',
#           'Sanya Malhotra', ''], dtype='<U20')},
#   {'number': '22.',
#    'name': 'Spider-Man: No Way Home',
#    'year': '(2021)',
#    'certificate': 'Tous publics',
#    'runtime': '148 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '8.3',
#    'metascore': '\n71        \n        Metascore\n            ',
#    'text-muted': "\nWith Spider-Man's identity now revealed, Peter asks Doctor Strange for help. When a spell goes wrong, dangerous foes from other worlds start to appear, forcing Peter to discover what it truly means to be Spider-Man.",
#    'director': array(['Jon Watts', '| '], dtype='<U22'),
#    'stars': array(['Tom Holland, ', 'Zendaya, ', 'Benedict Cumberbatch, ',
#           'Jacob Batalon', ''], dtype='<U22')},
#   {'number': '23.',
#    'name': 'Heat',
#    'year': '(1995)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '170 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.3',
#    'metascore': '\n76        \n        Metascore\n            ',
#    'text-muted': '\nA group of high-end professional thieves start to feel the heat from the LAPD when they unknowingly leave a clue at their latest heist.',
#    'director': array(['Michael Mann', '| '], dtype='<U16'),
#    'stars': array(['Al Pacino, ', 'Robert De Niro, ', 'Val Kilmer, ', 'Jon Voight',
#           ''], dtype='<U16')},
#   {'number': '24.',
#    'name': 'Le Retour du Jedi',
#    'year': '(1983)',
#    'certificate': 'Tous publics',
#    'runtime': '131 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '8.3',
#    'metascore': '\n58        \n        Metascore\n            ',
#    'text-muted': "\nAfter a daring mission to rescue Han Solo from Jabba the Hutt, the Rebels dispatch to Endor to destroy the second Death Star. Meanwhile, Luke struggles to help Darth Vader back from the dark side without falling into the Emperor's trap.",
#    'director': array(['Richard Marquand', '| '], dtype='<U18'),
#    'stars': array(['Mark Hamill, ', 'Harrison Ford, ', 'Carrie Fisher, ',
#           'Billy Dee Williams', ''], dtype='<U18')},
#   {'number': '25.',
#    'name': 'La mort aux trousses',
#    'year': '(1959)',
#    'certificate': 'Tous publics',
#    'runtime': '136 min',
#    'genre': '\nAction, Adventure, Mystery            ',
#    'rating': '8.3',
#    'metascore': '\n98        \n        Metascore\n            ',
#    'text-muted': '\nA New York City advertising executive goes on the run after being mistaken for a government agent by a group of foreign spies, and falls for a woman whose loyalties he begins to doubt.',
#    'director': array(['Alfred Hitchcock', '| '], dtype='<U19'),
#    'stars': array(['Cary Grant, ', 'Eva Marie Saint, ', 'James Mason, ',
#           'Jessie Royce Landis', ''], dtype='<U19')},
#   {'number': '26.',
#    'name': '1917',
#    'year': '(2019)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '119 min',
#    'genre': '\nAction, Drama, War            ',
#    'rating': '8.2',
#    'metascore': '\n78        \n        Metascore\n            ',
#    'text-muted': '\nApril 6th, 1917. As an infantry battalion assembles to wage war deep in enemy territory, two soldiers are assigned to race against time and deliver a message that will stop 1,600 men from walking straight into a deadly trap.',
#    'director': array(['Sam Mendes', '| '], dtype='<U22'),
#    'stars': array(['Dean-Charles Chapman, ', 'George MacKay, ', 'Daniel Mays, ',
#           'Colin Firth', ''], dtype='<U22')},
#   {'number': '27.',
#    'name': 'Warrior',
#    'year': '(2011)',
#    'certificate': 'Tous publics',
#    'runtime': '140 min',
#    'genre': '\nAction, Drama, Sport            ',
#    'rating': '8.2',
#    'metascore': '\n71        \n        Metascore\n            ',
#    'text-muted': "\nThe youngest son of an alcoholic former boxer returns home, where he's trained by his father for competition in a mixed martial arts tournament - a path that puts the fighter on a collision course with his estranged, older brother.",
#    'director': array(["Gavin O'Connor", '| '], dtype='<U17'),
#    'stars': array(['Tom Hardy, ', 'Nick Nolte, ', 'Joel Edgerton, ',
#           'Jennifer Morrison', ''], dtype='<U17')},
#   {'number': '28.',
#    'name': 'V pour vendetta',
#    'year': '(2005)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '132 min',
#    'genre': '\nAction, Drama, Sci-Fi            ',
#    'rating': '8.2',
#    'metascore': '\n62        \n        Metascore\n            ',
#    'text-muted': '\nIn a future British dystopian society, a shadowy freedom fighter, known only by the alias of "V", plots to overthrow the tyrannical government - with the help of a young woman.',
#    'director': array(['James McTeigue', '| '], dtype='<U17'),
#    'stars': array(['Hugo Weaving, ', 'Natalie Portman, ', 'Rupert Graves, ',
#           'Stephen Rea', ''], dtype='<U17')},
#   {'number': '29.',
#    'name': 'Batman Begins',
#    'year': '(2005)',
#    'certificate': 'Tous publics',
#    'runtime': '140 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.2',
#    'metascore': '\n70        \n        Metascore\n            ',
#    'text-muted': '\nAfter training with his mentor, Batman begins his fight to free crime-ridden Gotham City from corruption.',
#    'director': array(['Christopher Nolan', '| '], dtype='<U17'),
#    'stars': array(['Christian Bale, ', 'Michael Caine, ', 'Ken Watanabe, ',
#           'Liam Neeson', ''], dtype='<U17')},
#   {'number': '30.',
#    'name': 'Kill Bill: Volume I',
#    'year': '(2003)',
#    'certificate': '16',
#    'runtime': '111 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.2',
#    'metascore': '\n69        \n        Metascore\n            ',
#    'text-muted': '\nAfter awakening from a four-year coma, a former assassin wreaks vengeance on the team of assassins who betrayed her.',
#    'director': array(['Quentin Tarantino', '| '], dtype='<U17'),
#    'stars': array(['Uma Thurman, ', 'David Carradine, ', 'Daryl Hannah, ',
#           'Michael Madsen', ''], dtype='<U17')},
#   {'number': '31.',
#    'name': 'Arnaques, crimes et botanique',
#    'year': '(1998)',
#    'certificate': 'Tous publics',
#    'runtime': '107 min',
#    'genre': '\nAction, Comedy, Crime            ',
#    'rating': '8.2',
#    'metascore': '\n66        \n        Metascore\n            ',
#    'text-muted': '\nEddy persuades his three pals to pool money for a vital poker game against a powerful local mobster, Hatchet Harry. Eddy loses, after which Harry gives him a week to pay back 500,000 pounds.',
#    'director': array(['Guy Ritchie', '| '], dtype='<U17'),
#    'stars': array(['Jason Flemyng, ', 'Dexter Fletcher, ', 'Nick Moran, ',
#           'Jason Statham', ''], dtype='<U17')},
#   {'number': '32.',
#    'name': 'Jurassic Park',
#    'year': '(1993)',
#    'certificate': 'Tous publics',
#    'runtime': '127 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '8.2',
#    'metascore': '\n68        \n        Metascore\n            ',
#    'text-muted': "\nA pragmatic paleontologist touring an almost complete theme park on an island in Central America is tasked with protecting a couple of kids after a power failure causes the park's cloned dinosaurs to run loose.",
#    'director': array(['Steven Spielberg', '| '], dtype='<U20'),
#    'stars': array(['Sam Neill, ', 'Laura Dern, ', 'Jeff Goldblum, ',
#           'Richard Attenborough', ''], dtype='<U20')},
#   {'number': '33.',
#    'name': 'Indiana Jones et la dernière croisade',
#    'year': '(1989)',
#    'certificate': 'Tous publics',
#    'runtime': '127 min',
#    'genre': '\nAction, Adventure            ',
#    'rating': '8.2',
#    'metascore': '\n65        \n        Metascore\n            ',
#    'text-muted': '\nIn 1938, after his father Professor Henry Jones, Sr. goes missing while pursuing the Holy Grail, Professor Henry "Indiana" Jones, Jr. finds himself up against Adolf Hitler\'s Nazis again to stop them from obtaining its powers.',
#    'director': array(['Steven Spielberg', '| '], dtype='<U16'),
#    'stars': array(['Harrison Ford, ', 'Sean Connery, ', 'Alison Doody, ',
#           'Denholm Elliott', ''], dtype='<U16')},
#   {'number': '34.',
#    'name': 'Piège de cristal',
#    'year': '(1988)',
#    'certificate': 'Tous publics',
#    'runtime': '132 min',
#    'genre': '\nAction, Thriller            ',
#    'rating': '8.2',
#    'metascore': '\n72        \n        Metascore\n            ',
#    'text-muted': '\nAn NYPD officer tries to save his wife and several others taken hostage by German terrorists during a Christmas party at the Nakatomi Plaza in Los Angeles.',
#    'director': array(['John McTiernan', '| '], dtype='<U19'),
#    'stars': array(['Bruce Willis, ', 'Alan Rickman, ', 'Bonnie Bedelia, ',
#           'Reginald VelJohnson', ''], dtype='<U19')},
#   {'number': '35.',
#    'name': 'Le mécano de la Générale',
#    'year': '(1926)',
#    'certificate': 'Tous publics',
#    'runtime': '67 min',
#    'genre': '\nAction, Adventure, Comedy            ',
#    'rating': '8.2',
#    'metascore': 'NaN',
#    'text-muted': '\nAfter being rejected by the Confederate military, not realizing it was due to his crucial civilian role, an engineer must single-handedly recapture his beloved locomotive after it is seized by Union spies and return it through enemy lines.',
#    'director': array(['    Directors:', 'Clyde Bruckman, ', 'Buster Keaton', '| '],
#          dtype='<U16'),
#    'stars': array(['Buster Keaton, ', 'Marion Mack, ', 'Glen Cavender, ',
#           'Jim Farley', ''], dtype='<U16')},
#   {'number': '36.',
#    'name': 'Sherlock Junior',
#    'year': '(1924)',
#    'certificate': 'Tous publics',
#    'runtime': '45 min',
#    'genre': '\nAction, Comedy, Romance            ',
#    'rating': '8.2',
#    'metascore': 'NaN',
#    'text-muted': "\nA film projectionist longs to be a detective, and puts his meagre skills to work when he is framed by a rival for stealing his girlfriend's father's pocketwatch.",
#    'director': array(['Buster Keaton', '| '], dtype='<U17'),
#    'stars': array(['Buster Keaton, ', 'Kathryn McGuire, ', 'Joe Keaton, ',
#           'Erwin Connelly', ''], dtype='<U17')},
#   {'number': '37.',
#    'name': 'Everything Everywhere All at Once',
#    'year': '(2022)',
#    'certificate': 'Tous publics',
#    'runtime': '139 min',
#    'genre': '\nAction, Adventure, Comedy            ',
#    'rating': '8.1',
#    'metascore': '\n81        \n        Metascore\n            ',
#    'text-muted': '\nAn aging Chinese immigrant is swept up in an insane adventure, in which she alone can save the world by exploring other universes connecting with the lives she could have led.',
#    'director': array(['    Directors:', 'Dan Kwan, ', 'Daniel Scheinert', '| '],
#          dtype='<U18'),
#    'stars': array(['Michelle Yeoh, ', 'Stephanie Hsu, ', 'Jamie Lee Curtis, ',
#           'Ke Huy Quan', ''], dtype='<U18')},
#   {'number': '38.',
#    'name': 'Logan',
#    'year': '(2017)',
#    'certificate': '12 avec avertissement',
#    'runtime': '137 min',
#    'genre': '\nAction, Drama, Sci-Fi            ',
#    'rating': '8.1',
#    'metascore': '\n77        \n        Metascore\n            ',
#    'text-muted': '\nIn a future where mutants are nearly extinct, an elderly and weary Logan leads a quiet life. But when Laura, a mutant child pursued by scientists, comes to him for help, he must get her to safety.',
#    'director': array(['James Mangold', '| '], dtype='<U17'),
#    'stars': array(['Hugh Jackman, ', 'Patrick Stewart, ', 'Dafne Keen, ',
#           'Boyd Holbrook', ''], dtype='<U17')},
#   {'number': '39.',
#    'name': 'Rush',
#    'year': '(I) (2013)',
#    'certificate': 'Tous publics',
#    'runtime': '123 min',
#    'genre': '\nAction, Biography, Drama            ',
#    'rating': '8.1',
#    'metascore': '\n74        \n        Metascore\n            ',
#    'text-muted': '\nThe merciless 1970s rivalry between Formula One rivals James Hunt and Niki Lauda.',
#    'director': array(['Ron Howard', '| '], dtype='<U20'),
#    'stars': array(['Daniel Brühl, ', 'Chris Hemsworth, ', 'Olivia Wilde, ',
#           'Alexandra Maria Lara', ''], dtype='<U20')},
#   {'number': '40.',
#    'name': "Le Mans '66",
#    'year': '(2019)',
#    'certificate': 'Tous publics',
#    'runtime': '152 min',
#    'genre': '\nAction, Biography, Drama            ',
#    'rating': '8.1',
#    'metascore': '\n81        \n        Metascore\n            ',
#    'text-muted': '\nAmerican car designer Carroll Shelby and driver Ken Miles battle corporate interference and the laws of physics to build a revolutionary race car for Ford in order to defeat Ferrari at the 24 Hours of Le Mans in 1966.',
#    'director': array(['James Mangold', '| '], dtype='<U16'),
#    'stars': array(['Matt Damon, ', 'Christian Bale, ', 'Jon Bernthal, ',
#           'Caitríona Balfe', ''], dtype='<U16')},
#   {'number': '41.',
#    'name': 'Mad Max: Fury Road',
#    'year': '(2015)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '120 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '8.1',
#    'metascore': '\n90        \n        Metascore\n            ',
#    'text-muted': '\nIn a post-apocalyptic wasteland, a woman rebels against a tyrannical ruler in search for her homeland with the aid of a group of female prisoners, a psychotic worshiper, and a drifter named Max.',
#    'director': array(['George Miller', '| '], dtype='<U17'),
#    'stars': array(['Tom Hardy, ', 'Charlize Theron, ', 'Nicholas Hoult, ',
#           'Zoë Kravitz', ''], dtype='<U17')},
#   {'number': '42.',
#    'name': 'Dragons',
#    'year': '(2010)',
#    'certificate': 'Tous publics',
#    'runtime': '98 min',
#    'genre': '\nAnimation, Action, Adventure            ',
#    'rating': '8.1',
#    'metascore': '\n75        \n        Metascore\n            ',
#    'text-muted': '\nA hapless young Viking who aspires to hunt dragons becomes the unlikely friend of a young dragon himself, and learns there may be more to the creatures than he assumed.',
#    'director': array(['    Directors:', 'Dean DeBlois, ', 'Chris Sanders', '| '],
#          dtype='<U26'),
#    'stars': array(['Jay Baruchel, ', 'Gerard Butler, ', 'Christopher Mintz-Plasse, ',
#           'Craig Ferguson', ''], dtype='<U26')},
#   {'number': '43.',
#    'name': 'Pirates des Caraïbes : La malédiction du Black Pearl',
#    'year': '(2003)',
#    'certificate': 'Tous publics',
#    'runtime': '143 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '8.1',
#    'metascore': '\n63        \n        Metascore\n            ',
#    'text-muted': '\nBlacksmith Will Turner teams up with eccentric pirate "Captain" Jack Sparrow to save his love, the governor\'s daughter, from Jack\'s former pirate allies, who are now undead.',
#    'director': array(['Gore Verbinski', '| '], dtype='<U15'),
#    'stars': array(['Johnny Depp, ', 'Geoffrey Rush, ', 'Orlando Bloom, ',
#           'Keira Knightley', ''], dtype='<U15')},
#   {'number': '44.',
#    'name': 'Le géant de fer',
#    'year': '(1999)',
#    'certificate': 'Tous publics',
#    'runtime': '86 min',
#    'genre': '\nAnimation, Action, Adventure            ',
#    'rating': '8.1',
#    'metascore': '\n85        \n        Metascore\n            ',
#    'text-muted': '\nA young boy befriends a giant robot from outer space that a paranoid government agent wants to destroy.',
#    'director': array(['Brad Bird', '| '], dtype='<U19'),
#    'stars': array(['Eli Marienthal, ', 'Harry Connick Jr., ', 'Jennifer Aniston, ',
#           'Vin Diesel', ''], dtype='<U19')},
#   {'number': '45.',
#    'name': 'Terminator',
#    'year': '(1984)',
#    'certificate': '13',
#    'runtime': '107 min',
#    'genre': '\nAction, Sci-Fi            ',
#    'rating': '8.1',
#    'metascore': '\n84        \n        Metascore\n            ',
#    'text-muted': "\nA human soldier is sent from 2029 to 1984 to stop an almost indestructible cyborg killing machine, sent from the same year, which has been programmed to execute a young woman whose unborn son is the key to humanity's future salvation.",
#    'director': array(['James Cameron', '| '], dtype='<U23'),
#    'stars': array(['Arnold Schwarzenegger, ', 'Linda Hamilton, ', 'Michael Biehn, ',
#           'Paul Winfield', ''], dtype='<U23')},
#   {'number': '46.',
#    'name': 'Blade Runner',
#    'year': '(1982)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '117 min',
#    'genre': '\nAction, Drama, Sci-Fi            ',
#    'rating': '8.1',
#    'metascore': '\n84        \n        Metascore\n            ',
#    'text-muted': '\nA blade runner must pursue and terminate four replicants who stole a ship in space, and have returned to Earth to find their creator.',
#    'director': array(['Ridley Scott', '| '], dtype='<U18'),
#    'stars': array(['Harrison Ford, ', 'Rutger Hauer, ', 'Sean Young, ',
#           'Edward James Olmos', ''], dtype='<U18')},
#   {'number': '47.',
#    'name': "L'enfer est à lui",
#    'year': '(1949)',
#    'certificate': '16',
#    'runtime': '114 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.1',
#    'metascore': 'NaN',
#    'text-muted': '\nA psychopathic criminal with a mother complex makes a daring break from prison and leads his old gang in a chemical plant payroll heist.',
#    'director': array(['Raoul Walsh', '| '], dtype='<U17'),
#    'stars': array(['James Cagney, ', 'Virginia Mayo, ', "Edmond O'Brien, ",
#           'Margaret Wycherly', ''], dtype='<U17')},
#   {'number': '48.',
#    'name': 'Monte là-dessus!',
#    'year': '(1923)',
#    'certificate': 'Tous publics',
#    'runtime': '74 min',
#    'genre': '\nAction, Comedy, Thriller            ',
#    'rating': '8.1',
#    'metascore': 'NaN',
#    'text-muted': '\nA boy leaves his small country town and heads to the big city to get a job. As soon as he makes it big his sweetheart will join him and marry him. His enthusiasm to get ahead leads to some interesting adventures.',
#    'director': array(['    Directors:', 'Fred C. Newmeyer, ', 'Sam Taylor', '| '],
#          dtype='<U18'),
#    'stars': array(['Harold Lloyd, ', 'Mildred Davis, ', 'Bill Strother, ',
#           'Noah Young', ''], dtype='<U18')},
#   {'number': '49.',
#    'name': 'RRR',
#    'year': '(2022)',
#    'certificate': 'Tous publics',
#    'runtime': '187 min',
#    'genre': '\nAction, Drama            ',
#    'rating': '8.0',
#    'metascore': '\n83        \n        Metascore\n            ',
#    'text-muted': '\nA fictitious story about two legendary revolutionaries and their journey away from home before they started fighting for their country in the 1920s.',
#    'director': array(['S.S. Rajamouli', '| '], dtype='<U19'),
#    'stars': array(['N.T. Rama Rao Jr., ', 'Ram Charan Teja, ', 'Ajay Devgn, ',
#           'Alia Bhatt', ''], dtype='<U19')},
#   {'number': '50.',
#    'name': 'Les Gardiens de la Galaxie',
#    'year': '(2014)',
#    'certificate': 'Tous publics',
#    'runtime': '121 min',
#    'genre': '\nAction, Adventure, Comedy            ',
#    'rating': '8.0',
#    'metascore': '\n76        \n        Metascore\n            ',
#    'text-muted': '\nA group of intergalactic criminals must pull together to stop a fanatical warrior with plans to purge the universe.',
#    'director': array(['James Gunn', '| '], dtype='<U16'),
#    'stars': array(['Chris Pratt, ', 'Vin Diesel, ', 'Bradley Cooper, ', 'Zoe Saldana',
#           ''], dtype='<U16')}],
#  [{'number': '51.',
#    'name': 'Blade Runner 2049',
#    'year': '(2017)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '164 min',
#    'genre': '\nAction, Drama, Mystery            ',
#    'rating': '8.0',
#    'metascore': '\n81        \n        Metascore\n            ',
#    'text-muted': "\nYoung Blade Runner K's discovery of a long-buried secret leads him to track down former Blade Runner Rick Deckard, who's been missing for thirty years.",
#    'director': array(['Denis Villeneuve', '| '], dtype='<U16'),
#    'stars': array(['Harrison Ford, ', 'Ryan Gosling, ', 'Ana de Armas, ',
#           'Dave Bautista', ''], dtype='<U16')},
#   {'number': '52.',
#    'name': 'The Revenant',
#    'year': '(2015)',
#    'certificate': '12',
#    'runtime': '156 min',
#    'genre': '\nAction, Adventure, Drama            ',
#    'rating': '8.0',
#    'metascore': '\n76        \n        Metascore\n            ',
#    'text-muted': '\nA frontiersman on a fur trading expedition in the 1820s fights for survival after being mauled by a bear and left for dead by members of his own hunting team.',
#    'director': array(['Alejandro G. Iñárritu', '| '], dtype='<U21'),
#    'stars': array(['Leonardo DiCaprio, ', 'Tom Hardy, ', 'Will Poulter, ',
#           'Domhnall Gleeson', ''], dtype='<U21')},
#   {'number': '53.',
#    'name': 'Deadpool',
#    'year': '(2016)',
#    'certificate': '12',
#    'runtime': '108 min',
#    'genre': '\nAction, Adventure, Comedy            ',
#    'rating': '8.0',
#    'metascore': '\n65        \n        Metascore\n            ',
#    'text-muted': '\nA wisecracking mercenary gets experimented on and becomes immortal but ugly, and sets out to track down the man who ruined his looks.',
#    'director': array(['Tim Miller', '| '], dtype='<U17'),
#    'stars': array(['Ryan Reynolds, ', 'Morena Baccarin, ', 'T.J. Miller, ',
#           'Ed Skrein', ''], dtype='<U17')},
#   {'number': '54.',
#    'name': "Zack Snyder's Justice League",
#    'year': '(2021)',
#    'certificate': '12',
#    'runtime': '242 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '8.0',
#    'metascore': '\n54        \n        Metascore\n            ',
#    'text-muted': "\nDetermined to ensure that Superman's ultimate sacrifice wasn't in vain, Bruce Wayne recruits a team of metahumans to protect the world from an approaching threat of catastrophic proportions.",
#    'director': array(['Zack Snyder', '| '], dtype='<U14'),
#    'stars': array(['Henry Cavill, ', 'Ben Affleck, ', 'Gal Gadot, ', 'Amy Adams', ''],
#          dtype='<U14')},
#   {'number': '55.',
#    'name': 'Ip man',
#    'year': '(2008)',
#    'certificate': '12',
#    'runtime': '106 min',
#    'genre': '\nAction, Biography, Drama            ',
#    'rating': '8.0',
#    'metascore': '\n59        \n        Metascore\n            ',
#    'text-muted': '\nDuring the Japanese invasion of China, a wealthy martial artist is forced to leave his home when his city is occupied. With little means of providing for themselves, Ip Man and the remaining members of the city must find a way to survive.',
#    'director': array(['Wilson Yip', '| '], dtype='<U14'),
#    'stars': array(['Donnie Yen, ', 'Simon Yam, ', 'Siu-Wong Fan, ', 'Ka-Tung Lam', ''],
#          dtype='<U14')},
#   {'number': '56.',
#    'name': 'Dune',
#    'year': '(2021)',
#    'certificate': 'Tous publics',
#    'runtime': '155 min',
#    'genre': '\nAction, Adventure, Drama            ',
#    'rating': '8.0',
#    'metascore': '\n74        \n        Metascore\n            ',
#    'text-muted': "\nA noble family becomes embroiled in a war for control over the galaxy's most valuable asset while its heir becomes troubled by visions of a dark future.",
#    'director': array(['Denis Villeneuve', '| '], dtype='<U19'),
#    'stars': array(['Timothée Chalamet, ', 'Rebecca Ferguson, ', 'Zendaya, ',
#           'Oscar Isaac', ''], dtype='<U19')},
#   {'number': '57.',
#    'name': "Troupe d'élite",
#    'year': '(2007)',
#    'certificate': '16',
#    'runtime': '115 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.0',
#    'metascore': '\n33        \n        Metascore\n            ',
#    'text-muted': '\nIn 1997 Rio de Janeiro, Captain Nascimento has to find a substitute for his position while trying to take down drug dealers and criminals before the Pope visits.',
#    'director': array(['José Padilha', '| '], dtype='<U16'),
#    'stars': array(['Wagner Moura, ', 'André Ramiro, ', 'Caio Junqueira, ',
#           'Milhem Cortaz', ''], dtype='<U16')},
#   {'number': '58.',
#    'name': 'Avengers',
#    'year': '(2012)',
#    'certificate': 'Tous publics',
#    'runtime': '143 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '8.0',
#    'metascore': '\n69        \n        Metascore\n            ',
#    'text-muted': "\nEarth's mightiest heroes must come together and learn to fight as a team if they are going to stop the mischievous Loki and his alien army from enslaving humanity.",
#    'director': array(['Joss Whedon', '| '], dtype='<U20'),
#    'stars': array(['Robert Downey Jr., ', 'Chris Evans, ', 'Scarlett Johansson, ',
#           'Jeremy Renner', ''], dtype='<U20')},
#   {'number': '59.',
#    'name': 'La vengeance dans la peau',
#    'year': '(2007)',
#    'certificate': 'Tous publics',
#    'runtime': '115 min',
#    'genre': '\nAction, Mystery, Thriller            ',
#    'rating': '8.0',
#    'metascore': '\n85        \n        Metascore\n            ',
#    'text-muted': '\nJason Bourne dodges a ruthless C.I.A. official and his Agents from a new assassination program while searching for the origins of his life as a trained killer.',
#    'director': array(['Paul Greengrass', '| '], dtype='<U15'),
#    'stars': array(['Matt Damon, ', 'Edgar Ramírez, ', 'Joan Allen, ', 'Julia Stiles',
#           ''], dtype='<U15')},
#   {'number': '60.',
#    'name': 'Casino Royale',
#    'year': '(2006)',
#    'certificate': 'Tous publics avec avertissement',
#    'runtime': '144 min',
#    'genre': '\nAction, Adventure, Thriller            ',
#    'rating': '8.0',
#    'metascore': '\n80        \n        Metascore\n            ',
#    'text-muted': '\nAfter earning 00 status and a licence to kill, secret agent James Bond sets out on his first mission as 007. Bond must defeat a private banker funding terrorists in a high-stakes game of poker at Casino Royale, Montenegro.',
#    'director': array(['Martin Campbell', '| '], dtype='<U15'),
#    'stars': array(['Daniel Craig, ', 'Eva Green, ', 'Judi Dench, ', 'Jeffrey Wright',
#           ''], dtype='<U15')},
#   {'number': '61.',
#    'name': 'Kill Bill: Volume II',
#    'year': '(2004)',
#    'certificate': '12',
#    'runtime': '137 min',
#    'genre': '\nAction, Crime, Thriller            ',
#    'rating': '8.0',
#    'metascore': '\n83        \n        Metascore\n            ',
#    'text-muted': '\nThe Bride continues her quest of vengeance against her former boss and lover Bill, the reclusive bouncer Budd, and the treacherous, one-eyed Elle.',
#    'director': array(['Quentin Tarantino', '| '], dtype='<U17'),
#    'stars': array(['Uma Thurman, ', 'David Carradine, ', 'Michael Madsen, ',
#           'Daryl Hannah', ''], dtype='<U17')},
#   {'number': '62.',
#    'name': 'Infernal Affairs',
#    'year': '(2002)',
#    'certificate': '12',
#    'runtime': '101 min',
#    'genre': '\nAction, Crime, Drama            ',
#    'rating': '8.0',
#    'metascore': '\n75        \n        Metascore\n            ',
#    'text-muted': '\nA story between a mole in the police department and an undercover cop. Their objectives are the same: to find out who is the mole, and who is the cop.',
#    'director': array(['    Directors:', 'Andrew Lau, ', 'Alan Mak', '| '], dtype='<U24'),
#    'stars': array(['Andy Lau, ', 'Tony Chiu-Wai Leung, ', 'Anthony Chau-Sang Wong, ',
#           'Eric Tsang', ''], dtype='<U24')},
#   {'number': '63.',
#    'name': 'Les Indestructibles',
#    'year': '(2004)',
#    'certificate': 'Tous publics',
#    'runtime': '115 min',
#    'genre': '\nAnimation, Action, Adventure            ',
# ...
#    'stars': array(['Antonio Banderas, ', 'Lucy Liu, ', 'Talisa Soto, ', 'Gregg Henry',
#           ''], dtype='<U18')},
#   {'number': '2,064.',
#    'name': 'Donjons & dragons',
#    'year': '(2000)',
#    'certificate': 'Tous publics',
#    'runtime': '107 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '3.6',
#    'metascore': '\n14        \n        Metascore\n            ',
#    'text-muted': '\nProfion, a tyrant, attempts to overthrow a peaceful kingdom ruled by a tough empress.',
#    'director': array(['Courtney Solomon', '| '], dtype='<U16'),
#    'stars': array(['Justin Whalin, ', 'Jeremy Irons, ', 'Zoe McLellan, ',
#           'Bruce Payne', ''], dtype='<U16')},
#   {'number': '2,065.',
#    'name': 'Mortal kombat: Destruction finale',
#    'year': '(1997)',
#    'certificate': 'Tous publics',
#    'runtime': '95 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '3.6',
#    'metascore': '\n11        \n        Metascore\n            ',
#    'text-muted': '\nA group of martial-arts warriors has only six days to save the Earth from an extra-dimensional invasion.',
#    'director': array(['John R. Leonetti', '| '], dtype='<U16'),
#    'stars': array(['Robin Shou, ', 'Talisa Soto, ', 'James Remar, ', 'Sandra Hess',
#           ''], dtype='<U16')},
#   {'number': '2,066.',
#    'name': 'Spy Kids 4: Tout le temps du monde',
#    'year': '(2011)',
#    'certificate': 'PG',
#    'runtime': '89 min',
#    'genre': '\nAction, Adventure, Comedy            ',
#    'rating': '3.5',
#    'metascore': '\n37        \n        Metascore\n            ',
#    'text-muted': '\nA retired spy is called back into action, and to bond with her new step-children, she invites them along for the adventure to stop the evil Timekeeper from taking over the world.',
#    'director': array(['Robert Rodriguez', '| '], dtype='<U16'),
#    'stars': array(['Jessica Alba, ', 'Jeremy Piven, ', 'Joel McHale, ',
#           'Rowan Blanchard', ''], dtype='<U16')},
#   {'number': '2,067.',
#    'name': 'Dance Movie',
#    'year': '(2009)',
#    'certificate': 'PG-13',
#    'runtime': '83 min',
#    'genre': '\nAction, Comedy, Music            ',
#    'rating': '3.5',
#    'metascore': '\n40        \n        Metascore\n            ',
#    'text-muted': '\nStreet dancer Thomas Uncles is from the wrong side of the tracks, but his bond with the beautiful Megan White might help the duo realize their dreams as they enter in the mother of all dance battles.',
#    'director': array(['Damien Dante Wayans', '| '], dtype='<U19'),
#    'stars': array(['Marlon Wayans, ', 'Shawn Wayans, ', 'Shoshana Bush, ',
#           'Damon Wayans Jr.', ''], dtype='<U19')},
#   {'number': '2,068.',
#    'name': 'D-War - La guerre des dragons',
#    'year': '(2007)',
#    'certificate': 'Tous publics',
#    'runtime': '107 min',
#    'genre': '\nAction, Drama, Fantasy            ',
#    'rating': '3.5',
#    'metascore': '\n33        \n        Metascore\n            ',
#    'text-muted': '\nOnce in 500 years, ancient mythical creatures come to Earth, wreaking havoc and destruction. This time they must be stopped.',
#    'director': array(['Hyung-rae Shim', '| '], dtype='<U16'),
#    'stars': array(['Jason Behr, ', 'Amanda Brooks, ', 'Robert Forster, ',
#           'Craig Robinson', ''], dtype='<U16')},
#   {'number': '2,069.',
#    'name': 'Day of the Dead: Bloodline',
#    'year': '(2017)',
#    'certificate': '18',
#    'runtime': '90 min',
#    'genre': '\nAction, Drama, Horror            ',
#    'rating': '3.4',
#    'metascore': 'NaN',
#    'text-muted': '\nA small group of military personnel and survivalists dwell in an underground bunker as they seek to find a cure in a world overrun by zombies.',
#    'director': array(['Hèctor Hernández Vicens', '| '], dtype='<U23'),
#    'stars': array(['Sophie Skelton, ', 'Johnathon Schaech, ', 'Jeff Gum, ',
#           'Marcus Vanco', ''], dtype='<U23')},
#   {'number': '2,070.',
#    'name': 'Catwoman',
#    'year': '(2004)',
#    'certificate': 'Tous publics',
#    'runtime': '104 min',
#    'genre': '\nAction, Crime, Fantasy            ',
#    'rating': '3.4',
#    'metascore': '\n27        \n        Metascore\n            ',
#    'text-muted': '\nA shy woman, endowed with the speed, reflexes, and senses of a cat, walks a thin line between criminal and hero, even as a detective doggedly pursues her, fascinated by both of her personas.',
#    'director': array(['Pitof', '| '], dtype='<U16'),
#    'stars': array(['Halle Berry, ', 'Sharon Stone, ', 'Benjamin Bratt, ',
#           'Lambert Wilson', ''], dtype='<U16')},
#   {'number': '2,071.',
#    'name': 'Barb Wire',
#    'year': '(1996)',
#    'certificate': '12',
#    'runtime': '98 min',
#    'genre': '\nAction, Sci-Fi            ',
#    'rating': '3.4',
#    'metascore': '\n40        \n        Metascore\n            ',
#    'text-muted': '\nDuring the Second American Civil War in 2017, Barb Wire owns a nightclub called the Hammerhead. Things become complicated when her ex-lover Axel Hood, who is married to the fugitive Corrina Devonshire, re-enters her life.',
#    'director': array(['David Hogan', '| '], dtype='<U19'),
#    'stars': array(['Pamela Anderson, ', 'Amir AboulEla, ', 'Adriana Alexander, ',
#           'David Andriole', ''], dtype='<U19')},
#   {'number': '2,072.',
#    'name': 'Hard Kill',
#    'year': '(2020)',
#    'certificate': 'Tous publics',
#    'runtime': '98 min',
#    'genre': '\nAction, Thriller            ',
#    'rating': '3.3',
#    'metascore': 'NaN',
#    'text-muted': '\nThe work of billionaire tech CEO Donovan Chalmers (Willis) is so valuable that he hires mercenaries to protect it, and a terrorist group kidnaps his daughter just to get it.',
#    'director': array(['Matt Eskandari', '| '], dtype='<U17'),
#    'stars': array(['Jesse Metcalfe, ', 'Bruce Willis, ', 'Lala Kent, ',
#           'Natalie Eva Marie', ''], dtype='<U17')},
#   {'number': '2,073.',
#    'name': 'Far Cry Warrior',
#    'year': '(2008)',
#    'certificate': 'Accord parental',
#    'runtime': '95 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '3.2',
#    'metascore': 'NaN',
#    'text-muted': '\nAn ex-special forces soldier turned boatman is hired by a journalist to investigate a top-secret military base on a nearby island.',
#    'director': array(['Uwe Boll', '| '], dtype='<U20'),
#    'stars': array(['Til Schweiger, ', 'Emmanuelle Vaugier, ', 'Natalia Avelon, ',
#           'Udo Kier', ''], dtype='<U20')},
#   {'number': '2,074.',
#    'name': 'Captain America',
#    'year': '(1990)',
#    'certificate': 'Tous Public',
#    'runtime': '97 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '3.2',
#    'metascore': 'NaN',
#    'text-muted': '\nFrozen in the ice for decades, Captain America is freed to battle against archcriminal The Red Skull.',
#    'director': array(['Albert Pyun', '| '], dtype='<U15'),
#    'stars': array(['Matt Salinger, ', 'Ronny Cox, ', 'Ned Beatty, ', 'Darren McGavin',
#           ''], dtype='<U15')},
#   {'number': '2,075.',
#    'name': 'Le chaos',
#    'year': '(I) (2014)',
#    'certificate': 'PG-13',
#    'runtime': '110 min',
#    'genre': '\nAction, Fantasy, Sci-Fi            ',
#    'rating': '3.1',
#    'metascore': '\n12        \n        Metascore\n            ',
#    'text-muted': '\nA small group of survivors are left behind after millions of people suddenly vanish and the world is plunged into chaos and destruction.',
#    'director': array(['Vic Armstrong', '| '], dtype='<U19'),
#    'stars': array(['Nicolas Cage, ', 'Lea Thompson, ', 'Cassi Thomson, ',
#           'Chad Michael Murray', ''], dtype='<U19')},
#   {'number': '2,076.',
#    'name': 'Rollerball',
#    'year': '(2002)',
#    'certificate': '12',
#    'runtime': '98 min',
#    'genre': '\nAction, Sci-Fi, Sport            ',
#    'rating': '3.1',
#    'metascore': '\n14        \n        Metascore\n            ',
#    'text-muted': '\nThe big thing in 2005 is a violent sport which can have some pretty serious consequences... like dying.',
#    'director': array(['John McTiernan', '| '], dtype='<U14'),
#    'stars': array(['Chris Klein, ', 'Jean Reno, ', 'LL Cool J, ', 'Rebecca Romijn',
#           ''], dtype='<U14')},
#   {'number': '2,077.',
#    'name': 'Anti Life',
#    'year': '(IV) (2020)',
#    'certificate': 'R',
#    'runtime': '92 min',
#    'genre': '\nAction, Horror, Sci-Fi            ',
#    'rating': '3.0',
#    'metascore': 'NaN',
#    'text-muted': '\nOn the cusp of fatherhood, a junior mechanic aboard an interstellar ark to New Earth must outwit a malevolent cosmic terror intent on using the spaceship as a weapon.',
#    'director': array(['John Suits', '| '], dtype='<U18'),
#    'stars': array(['Cody Kearsley, ', 'Bruce Willis, ', 'Rachel Nichols, ',
#           'Kassandra Clementi', ''], dtype='<U18')},
#   {'number': '2,078.',
#    'name': 'BloodRayne',
#    'year': '(2005)',
#    'certificate': '16',
#    'runtime': '95 min',
#    'genre': '\nAction, Fantasy, Horror            ',
#    'rating': '2.9',
#    'metascore': '\n18        \n        Metascore\n            ',
#    'text-muted': '\nIn the eighteenth century, a vampire escapes from the freak show, in which she once participated, and teams up with a group of vampire slayers to kill the man who raped her mother.',
#    'director': array(['Uwe Boll', '| '], dtype='<U20'),
#    'stars': array(['Kristanna Loken, ', 'Ben Kingsley, ', 'Michelle Rodriguez, ',
#           'Michael Madsen', ''], dtype='<U20')},
#   {'number': '2,079.',
#    'name': "Justicier d'acier",
#    'year': '(1997)',
#    'certificate': 'PG-13',
#    'runtime': '97 min',
#    'genre': '\nAction, Adventure, Crime            ',
#    'rating': '2.9',
#    'metascore': '\n28        \n        Metascore\n            ',
#    'text-muted': '\nA scientist for the military turns himself into a cartoon-like superhero when a version of one of his own weapons is being used against enemies.',
#    'director': array(['Kenneth Johnson', '| '], dtype='<U18'),
#    'stars': array(["Shaquille O'Neal, ", 'Annabeth Gish, ', 'Judd Nelson, ',
#           'Richard Roundtree', ''], dtype='<U18')},
#   {'number': '2,080.',
#    'name': 'Les 3 ninjas se déchaînent',
#    'year': '(1998)',
#    'certificate': 'Tous publics',
#    'runtime': '93 min',
#    'genre': '\nAction, Adventure, Comedy            ',
#    'rating': '2.9',
#    'metascore': '\n44        \n        Metascore\n            ',
#    'text-muted': '\nThe three unstoppable Ninja brothers fight to save their hero (Hulk Hogan) and Mega Mountain Amusement Park from the vicious kid-hating Medusa (Loni Anderson).',
#    'director': array(['Sean McNamara', '| '], dtype='<U15'),
#    'stars': array(['Loni Anderson, ', 'Hulk Hogan, ', 'Jim Varney, ', 'Victor Wong',
#           ''], dtype='<U15')},
#   {'number': '2,081.',
#    'name': 'Dragonball Evolution',
#    'year': '(2009)',
#    'certificate': 'Tous publics',
#    'runtime': '85 min',
#    'genre': '\nAction, Adventure, Fantasy            ',
#    'rating': '2.6',
#    'metascore': '\n45        \n        Metascore\n            ',
#    'text-muted': '\nThe young warrior Son Goku sets out on a quest, racing against time and the vengeful King Piccolo, to collect a set of seven magical orbs that will grant their wielder unlimited power.',
#    'director': array(['James Wong', '| '], dtype='<U16'),
#    'stars': array(['Justin Chatwin, ', 'James Marsters, ', 'Chow Yun-Fat, ',
#           'Emmy Rossum', ''], dtype='<U16')},
#   {'number': '2,082.',
#    'name': 'Laxmii',
#    'year': '(2020)',
#    'certificate': 'NaN',
#    'runtime': '141 min',
#    'genre': '\nAction, Comedy, Horror            ',
#    'rating': '2.6',
#    'metascore': 'NaN',
#    'text-muted': "\nAasif visits his wife's parents' house and happens to go to a ground that is supposedly haunted. However, he is soon possessed by the spirit of a transgender who is out for revenge.",
#    'director': array(['    Directors:', 'Lawrence Raghavendra, ', 'Balakrishnan Thevar',
#           '| '], dtype='<U22'),
#    'stars': array(['Akshay Kumar, ', 'Kiara Advani, ', 'Sharad Kelkar, ',
#           'Ashwini Kalsekar', ''], dtype='<U22')},
#   {'number': '2,083.',
#    'name': 'Cosmic Sin',
#    'year': '(2021)',
#    'certificate': '10',
#    'runtime': '88 min',
#    'genre': '\nAction, Sci-Fi            ',
#    'rating': '2.5',
#    'metascore': '\n9        \n        Metascore\n            ',
#    'text-muted': '\nSeven rogue soldiers launch a preemptive strike against a newly discovered alien civilization in the hopes of ending an interstellar war before it starts.',
#    'director': array(['Edward Drake', '| '], dtype='<U20'),
#    'stars': array(['Frank Grillo, ', 'Bruce Willis, ', 'Brandon Thomas Lee, ',
#           'Corey Large', ''], dtype='<U20')},
#   {'number': '2,084.',
#    'name': 'Battlefield Earth - Terre champ de bataille',
#    'year': '(2000)',
#    'certificate': 'Tous publics',
#    'runtime': '118 min',
#    'genre': '\nAction, Adventure, Sci-Fi            ',
#    'rating': '2.5',
#    'metascore': '\n9        \n        Metascore\n            ',
#    'text-muted': "\nIt's the year 3000 A.D., and the Earth is lost to the alien race of Psychlos. Humanity is enslaved by these gold-thirsty tyrants, who are unaware that their 'man-animals' are about to ignite the rebellion of a lifetime.",
#    'director': array(['Roger Christian', '| '], dtype='<U17'),
#    'stars': array(['John Travolta, ', 'Forest Whitaker, ', 'Barry Pepper, ',
#           'Kim Coates', ''], dtype='<U17')},
#   {'number': '2,085.',
#    'name': 'Alone in the Dark',
#    'year': '(2005)',
#    'certificate': 'R',
#    'runtime': '99 min',
#    'genre': '\nAction, Horror, Sci-Fi            ',
#    'rating': '2.4',
#    'metascore': '\n9        \n        Metascore\n            ',
#    'text-muted': '\nA detective of the paranormal slowly unravels mysterious events with deadly results.',
#    'director': array(['Uwe Boll', '| '], dtype='<U18'),
#    'stars': array(['Christian Slater, ', 'Tara Reid, ', 'Stephen Dorff, ',
#           'Frank C. Turner', ''], dtype='<U18')},
#   {'number': '2,086.',
#    'name': 'The Prototype',
#    'year': '(2022)',
#    'certificate': 'NaN',
#    'runtime': '97 min',
#    'genre': '\nAction, Sci-Fi, Thriller            ',
#    'rating': '2.2',
#    'metascore': 'NaN',
#    'text-muted': '\nA government agent stumbles upon an alien conspiracy to conquer Earth. Using a blue liquid created by the aliens to make soldiers stronger, he becomes The Prototype-the only hope for mankind.',
#    'director': array(['Marcelo Grion', '| '], dtype='<U18'),
#    'stars': array(['Ameerah Abdullah, ', 'Zia Alexander, ', 'Jacob Baeza, ',
#           'Ken Belsky', ''], dtype='<U18')},
#   {'number': '2,087.',
#    'name': 'House of the Dead',
#    'year': '(2003)',
#    'certificate': '16',
#    'runtime': '90 min',
#    'genre': '\nAction, Adventure, Horror            ',
#    'rating': '2.1',
#    'metascore': '\n15        \n        Metascore\n            ',
#    'text-muted': '\nA group of college students travels to a mysterious island to attend a rave, which is soon taken over by bloodthirsty zombies.',
#    'director': array(['Uwe Boll', '| '], dtype='<U17'),
#    'stars': array(['Jonathan Cherry, ', 'Tyron Leitso, ', 'Clint Howard, ',
#           'Ona Grauer', ''], dtype='<U17')},
#   {'number': '2,088.',
#    'name': "L'homme qui sauva le monde - Le retour",
#    'year': '(2006)',
#    'certificate': 'Tous Public',
#    'runtime': '110 min',
#    'genre': '\nAction, Comedy, Sci-Fi            ',
#    'rating': '1.5',
#    'metascore': 'NaN',
#    'text-muted': '\nA family of Turks try to adapt to life in a new solar system.',
#    'director': array(['Kartal Tibet', '| '], dtype='<U18'),
#    'stars': array(['Cüneyt Arkin, ', 'Miraç Bayramoglu, ', 'Haldun Boysan, ',
#           'Berda Ceyhan', ''], dtype='<U18')},
#   {'number': '2,089.',
#    'name': 'Foodfight!',
#    'year': '(2012)',
#    'certificate': 'PG',
#    'runtime': '91 min',
#    'genre': '\nAnimation, Action, Adventure            ',
#    'rating': '1.3',
#    'metascore': 'NaN',
#    'text-muted': '\nThe evil Brand X joins a supermarket that becomes a city after closing time.',
#    'director': array(['Lawrence Kasanoff', '| '], dtype='<U17'),
#    'stars': array(['Hilary Duff, ', 'Haylie Duff, ', 'Charlie Sheen, ',
#           'Eva Longoria', ''], dtype='<U17')}]]

# %%
for k in df:
    if len(df) != 150:
        print(len(df))

# %%
t_df = pd.concat([pd.DataFrame(d) for d in df])

# %%
t_df
# Out:
#     number                                        name    year   certificate  \
# 0       1.         The Dark Knight : Le Chevalier noir  (2008)  Tous publics
# 1       2.  Le Seigneur des anneaux : Le Retour du roi  (2003)  Tous publics
# 2       3.          Kill Bill: The Whole Bloody Affair  (2011)           NaN
# 3       4.                                   Inception  (2010)  Tous publics
# 4       5.    Le Seigneur des anneaux : Les Deux Tours  (2002)  Tous publics
# ..     ...                                         ...     ...           ...
# 34  2,085.                           Alone in the Dark  (2005)             R
# 35  2,086.                               The Prototype  (2022)           NaN
# 36  2,087.                           House of the Dead  (2003)            16
# 37  2,088.      L'homme qui sauva le monde - Le retour  (2006)   Tous Public
# 38  2,089.                                  Foodfight!  (2012)            PG
#
#     runtime                                       genre rating  \
# 0   152 min          \nAction, Crime, Drama                9.0
# 1   201 min      \nAction, Adventure, Drama                9.0
# 2   247 min       \nAction, Crime, Thriller                8.8
# 3   148 min     \nAction, Adventure, Sci-Fi                8.8
# 4   179 min      \nAction, Adventure, Drama                8.8
# ..      ...                                         ...    ...
# 34   99 min        \nAction, Horror, Sci-Fi                2.4
# 35   97 min      \nAction, Sci-Fi, Thriller                2.2
# 36   90 min     \nAction, Adventure, Horror                2.1
# 37  110 min        \nAction, Comedy, Sci-Fi                1.5
# 38   91 min  \nAnimation, Action, Adventure                1.3
#
#                                         metascore  \
# 0   \n84        \n        Metascore\n
# 1   \n94        \n        Metascore\n
# 2                                             NaN
# 3   \n74        \n        Metascore\n
# 4   \n87        \n        Metascore\n
# ..                                            ...
# 34   \n9        \n        Metascore\n
# 35                                            NaN
# 36  \n15        \n        Metascore\n
# 37                                            NaN
# 38                                            NaN
#
#                                            text-muted  \
# 0   \nWhen the menace known as the Joker wreaks ha...
# 1   \nGandalf and Aragorn lead the World of Men ag...
# 2   \nThe Bride must kill her ex-boss and lover Bi...
# 3   \nA thief who steals corporate secrets through...
# 4   \nWhile Frodo and Sam edge closer to Mordor wi...
# ..                                                ...
# 34  \nA detective of the paranormal slowly unravel...
# 35  \nA government agent stumbles upon an alien co...
# 36  \nA group of college students travels to a mys...
# 37  \nA family of Turks try to adapt to life in a ...
# 38  \nThe evil Brand X joins a supermarket that be...
#
#                    director                                              stars
# 0   [Christopher Nolan, | ]  [Christian Bale, , Heath Ledger, , Aaron Eckha...
# 1       [Peter Jackson, | ]  [Elijah Wood, , Viggo Mortensen, , Ian McKelle...
# 2   [Quentin Tarantino, | ]  [Uma Thurman, , Lucy Liu, , Vivica A. Fox, , M...
# 3   [Christopher Nolan, | ]  [Leonardo DiCaprio, , Joseph Gordon-Levitt, , ...
# 4       [Peter Jackson, | ]  [Elijah Wood, , Ian McKellen, , Viggo Mortense...
# ..                      ...                                                ...
# 34           [Uwe Boll, | ]  [Christian Slater, , Tara Reid, , Stephen Dorf...
# 35      [Marcelo Grion, | ]  [Ameerah Abdullah, , Zia Alexander, , Jacob Ba...
# 36           [Uwe Boll, | ]  [Jonathan Cherry, , Tyron Leitso, , Clint Howa...
# 37       [Kartal Tibet, | ]  [Cüneyt Arkin, , Miraç Bayramoglu, , Haldun Bo...
# 38  [Lawrence Kasanoff, | ]  [Hilary Duff, , Haylie Duff, , Charlie Sheen, ...
#
# [2089 rows x 11 columns]

# %%
t_df = cleanPage(t_df)

# %%
t_df
# Out:
#                                           name  year   certificate  runtime  \
# 0          The Dark Knight : Le Chevalier noir  2008  Tous publics      152
# 1   Le Seigneur des anneaux : Le Retour du roi  2003  Tous publics      201
# 2           Kill Bill: The Whole Bloody Affair  2011           NaN      247
# 3                                    Inception  2010  Tous publics      148
# 4     Le Seigneur des anneaux : Les Deux Tours  2002  Tous publics      179
# ..                                         ...   ...           ...      ...
# 34                           Alone in the Dark  2005             R       99
# 35                               The Prototype  2022           NaN       97
# 36                           House of the Dead  2003            16       90
# 37      L'homme qui sauva le monde - Le retour  2006   Tous Public      110
# 38                                  Foodfight!  2012            PG       91
#
#                                           genre  rating  metascore  \
# 0           [ction,  Crime,  Drama            ]     9.0         84
# 1       [ction,  Adventure,  Drama            ]     9.0         94
# 2        [ction,  Crime,  Thriller            ]     8.8         -1
# 3      [ction,  Adventure,  Sci-Fi            ]     8.8         74
# 4       [ction,  Adventure,  Drama            ]     8.8         87
# ..                                          ...     ...        ...
# 34        [ction,  Horror,  Sci-Fi            ]     2.4          9
# 35      [ction,  Sci-Fi,  Thriller            ]     2.2         -1
# 36     [ction,  Adventure,  Horror            ]     2.1         15
# 37        [ction,  Comedy,  Sci-Fi            ]     1.5         -1
# 38  [nimation,  Action,  Adventure            ]     1.3         -1
#
#                                            text-muted  \
# 0   When the menace known as the Joker wreaks havo...
# 1   Gandalf and Aragorn lead the World of Men agai...
# 2   The Bride must kill her ex-boss and lover Bill...
# 3   A thief who steals corporate secrets through t...
# 4   While Frodo and Sam edge closer to Mordor with...
# ..                                                ...
# 34  A detective of the paranormal slowly unravels ...
# 35  A government agent stumbles upon an alien cons...
# 36  A group of college students travels to a myste...
# 37  A family of Turks try to adapt to life in a ne...
# 38  The evil Brand X joins a supermarket that beco...
#
#                      director  \
# 0   [Christopher Nolan, None]
# 1       [Peter Jackson, None]
# 2   [Quentin Tarantino, None]
# 3   [Christopher Nolan, None]
# 4       [Peter Jackson, None]
# ..                        ...
# 34           [Uwe Boll, None]
# 35      [Marcelo Grion, None]
# 36           [Uwe Boll, None]
# 37       [Kartal Tibet, None]
# 38  [Lawrence Kasanoff, None]
#
#                                                 stars
# 0   [Christian Bale, Heath Ledger, Aaron Eckhart, ...
# 1   [Elijah Wood, Viggo Mortensen, Ian McKellen, O...
# 2   [Uma Thurman, Lucy Liu, Vivica A. Fox, Michael...
# 3   [Leonardo DiCaprio, Joseph Gordon-Levitt, Elli...
# 4   [Elijah Wood, Ian McKellen, Viggo Mortensen, O...
# ..                                                ...
# 34  [Christian Slater, Tara Reid, Stephen Dorff, F...
# 35  [Ameerah Abdullah, Zia Alexander, Jacob Baeza,...
# 36  [Jonathan Cherry, Tyron Leitso, Clint Howard, ...
# 37  [Cüneyt Arkin, Miraç Bayramoglu, Haldun Boysan...
# 38  [Hilary Duff, Haylie Duff, Charlie Sheen, Eva ...
#
# [2089 rows x 10 columns]

# %%
t_df.shape
# Out:
# (2089, 10)

# %%
t_df.dtypes
# Out:
# name            object
# year            object
# certificate     object
# runtime          int32
# genre           object
# rating         float64
# metascore        int64
# text-muted      object
# director        object
# stars           object
# dtype: object

# %%
t_df.to_csv("./data_imdb_action.csv")

# %%
df2 = pd.read_csv("data_imdb_action.csv", sep=",")

# %%
df2
# Out:
#       Unnamed: 0                                        name  year  \
# 0              0         The Dark Knight : Le Chevalier noir  2008
# 1              1  Le Seigneur des anneaux : Le Retour du roi  2003
# 2              2          Kill Bill: The Whole Bloody Affair  2011
# 3              3                                   Inception  2010
# 4              4    Le Seigneur des anneaux : Les Deux Tours  2002
# ...          ...                                         ...   ...
# 2084          34                           Alone in the Dark  2005
# 2085          35                               The Prototype  2022
# 2086          36                           House of the Dead  2003
# 2087          37      L'homme qui sauva le monde - Le retour  2006
# 2088          38                                  Foodfight!  2012
#
#        certificate  runtime  \
# 0     Tous publics      152
# 1     Tous publics      201
# 2              NaN      247
# 3     Tous publics      148
# 4     Tous publics      179
# ...            ...      ...
# 2084             R       99
# 2085           NaN       97
# 2086            16       90
# 2087   Tous Public      110
# 2088            PG       91
#
#                                                   genre  rating  metascore  \
# 0             ['ction', ' Crime', ' Drama            ']     9.0         84
# 1         ['ction', ' Adventure', ' Drama            ']     9.0         94
# 2          ['ction', ' Crime', ' Thriller            ']     8.8         -1
# 3        ['ction', ' Adventure', ' Sci-Fi            ']     8.8         74
# 4         ['ction', ' Adventure', ' Drama            ']     8.8         87
# ...                                                 ...     ...        ...
# 2084        ['ction', ' Horror', ' Sci-Fi            ']     2.4          9
# 2085      ['ction', ' Sci-Fi', ' Thriller            ']     2.2         -1
# 2086     ['ction', ' Adventure', ' Horror            ']     2.1         15
# 2087        ['ction', ' Comedy', ' Sci-Fi            ']     1.5         -1
# 2088  ['nimation', ' Action', ' Adventure            ']     1.3         -1
#
#                                              text-muted  \
# 0     When the menace known as the Joker wreaks havo...
# 1     Gandalf and Aragorn lead the World of Men agai...
# 2     The Bride must kill her ex-boss and lover Bill...
# 3     A thief who steals corporate secrets through t...
# 4     While Frodo and Sam edge closer to Mordor with...
# ...                                                 ...
# 2084  A detective of the paranormal slowly unravels ...
# 2085  A government agent stumbles upon an alien cons...
# 2086  A group of college students travels to a myste...
# 2087  A family of Turks try to adapt to life in a ne...
# 2088  The evil Brand X joins a supermarket that beco...
#
#                          director  \
# 0     ['Christopher Nolan', None]
# 1         ['Peter Jackson', None]
# 2     ['Quentin Tarantino', None]
# 3     ['Christopher Nolan', None]
# 4         ['Peter Jackson', None]
# ...                           ...
# 2084           ['Uwe Boll', None]
# 2085      ['Marcelo Grion', None]
# 2086           ['Uwe Boll', None]
# 2087       ['Kartal Tibet', None]
# 2088  ['Lawrence Kasanoff', None]
#
#                                                   stars
# 0     ['Christian Bale', 'Heath Ledger', 'Aaron Eckh...
# 1     ['Elijah Wood', 'Viggo Mortensen', 'Ian McKell...
# 2     ['Uma Thurman', 'Lucy Liu', 'Vivica A. Fox', '...
# 3     ['Leonardo DiCaprio', 'Joseph Gordon-Levitt', ...
# 4     ['Elijah Wood', 'Ian McKellen', 'Viggo Mortens...
# ...                                                 ...
# 2084  ['Christian Slater', 'Tara Reid', 'Stephen Dor...
# 2085  ['Ameerah Abdullah', 'Zia Alexander', 'Jacob B...
# 2086  ['Jonathan Cherry', 'Tyron Leitso', 'Clint How...
# 2087  ['Cüneyt Arkin', 'Miraç Bayramoglu', 'Haldun B...
# 2088  ['Hilary Duff', 'Haylie Duff', 'Charlie Sheen'...
#
# [2089 rows x 11 columns]
